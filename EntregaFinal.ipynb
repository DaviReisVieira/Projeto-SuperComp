# %% [markdown]
# # Relatório Parcial : Maratona de Filmes
#
# Aluno: Davi Reis Vieira de Souza

# %% [markdown]
# ## Introdução
#
# Queremos passar um final de semana assistindo ao máximo de filmes possível, mas há restrições quanto aos horários disponíveis e ao número de títulos que podem ser vistos em cada categoria (comédia, drama, ação, etc).
#
# **Entrada**: Um inteiro N representando o número de filmes disponíveis para assistir e N trios de inteiros (H[i], F[i], C[i]), representando a hora de início, a hora de fim e a categoria do i-ésimo filme. Além disso, um inteiro M representando o número de categorias e uma lista de M inteiros representando o número máximo de filmes que podem ser assistidos em cada categoria.
#
# **Saída**: Um inteiro representando o número máximo de filmes que podem ser assistidos de acordo com as restrições de horários e número máximo por categoria.
#
# Abaixo, temos o seguinte exemplo de *input*:
#
# ```txt
# 10 4
# 1 3 1 2
# 11 13 3
# 14 15 3
# 10 16 2
# ```
#
# Como ler esse arquivo?
#
# - A primeira linha indica que há 10 filmes a serem considerados e 4 categorias;
# - a segunda linha indica qual o máximo de filmes que cada categoria pode ter;
# - da terceira linha em diante você vai encontrar os n filmes, suas respectivas hora de início, hora de término e categoria pertencente.

# %% [markdown]
# ## Objetivo
#
# O objetivo do projeto é conseguir agrupar o máximo de filmes que podem ser assistidos em um dia conforme as instruções e as instruções dadas.

# %% [markdown]
# ## Heurística Gulosa, Aleatorização, Paralelismo com OpenMP e Paralelismo com GRU

# %% [markdown]
# ### Heuristica Gulosa
#
# A heurística gulosa é um algoritmo que resolve problemas de otimização tentando encontrar a melhor solução possível em cada etapa, sem olhar para o resultado final. No caso do problema da *Maratona de Filmes*, a heurística gulosa funciona da seguinte forma:
#
# - Ordena os filmes em ordem crescente do horário de fim;
# - Aplicaam-se as restrições e escolhe-se o primeiro filme que as possuiam de acordo com os horários de fim;
# - Quando não houver mais espaço livre na *Maratona*, a heurística termina.
#
# A heurística gulosa é usada para encontrar soluções ótimas em problemas de otimização, mas nem sempre garante a melhor solução. No entanto, é útil para problemas grandes em que encontrar a solução ótima é difícil. O algoritmo pode ser modificado e combinado com outras técnicas para melhorar a qualidade da solução encontrada.

# %% [markdown]
# ### Heuristica Gulosa com Aleatorização
#
# Essa implementação consiste na adaptação da heurística gulosa de nosso projeto. A proposta é que modifiquemos a heurística gulosa de modo que ao longo da seleção de um filme, hajam 25% de chance de pegar outro filme qualquer que respeite o mesmo horário analisado. Isso fará com que a heurística tenha um pouco mais de exploration e os resultados sejam melhores, pois a heurística não ficará presa em um ótimo local.
#
# Além disso, como ela possui o caráter aleatório, ela pode ser usada para encontrar soluções diferentes para o mesmo problema, o que pode ser útil para encontrar soluções melhores.

# %% [markdown]
# ### Paralelismo com OpenMP
#
# Até aquele momento, haviam sido experimentadas heurísticas que visavam resolver o problema em um tempo razoável, sem oferecer garantias de otimalidade. Agora, surge a necessidade de incorporar o paralelismo de tarefas nas alternativas de resolução.
#
# Com o objetivo de introduzir o paralelismo, a implementação exaustiva precisará ser modificada. A diretiva ``#pragma omp parallel for`` pode ser utilizada para distribuir as iterações de um loop entre as threads disponíveis. Dentro desse loop, cada filme pode ser verificado individualmente e, caso esteja dentro das restrições de horário e categoria, uma variável compartilhada chamada ``"count"`` será incrementada. É importante ressaltar que, por se tratar de uma variável compartilhada, a região crítica precisa ser preservada entre as threads.
#
# É relevante destacar que a utilização do OpenMP não necessariamente garantirá um melhor desempenho, pois a paralelização implica em um overhead que pode diminuir o desempenho do programa em alguns casos. É fundamental realizar testes para verificar se a utilização do OpenMP é verdadeiramente benéfica para o problema em questão.

# %% [markdown]
# ### Paralelismo com GPU
#
# A implementação com GPU foi feita utilizando a biblioteca Thrust. Será utilizada a busca exaustiva para encontrar a solução ótima do problema. A busca exaustiva consiste em testar todas as possibilidades de solução para o problema e escolher a melhor. Para isso, é necessário testar todas as combinações de filmes que podem ser assistidos.

# %% [markdown]
# ## O Código

# %% [markdown]
# ### Heuristica Gulosa
#
# Abaixo, a explicação por partes principais do código:
#
# #### Bibliotecas
#
# ```cpp
# #include <iostream>
# #include <vector>
# #include <algorithm>
# #include <iomanip>
# #include <bitset>
# ```
#
# São as bibliotecas padrões da linguagem C++. `iostream` é para entrada e saída de dados, ``vector`` é para armazenar listas de objetos, ``algorithm`` é para algoritmos de ordenação e outras operações em contêineres, ``iomanip`` é para manipulação de fluxos de saída e ``bitset`` é para manipulação de bits.
#
# #### Estruturas de Dados
#
# ```cpp
# struct Filme {
#     int id;
#     int inicio;
#     int fim;
#     int categoria;
#     std::bitset<24> horario;
# };
#
# struct Categoria {
#     int id;
#     int quantidade;
# };
#
# struct Maratona {
#     std::bitset<24> disponibilidade;
#     std::vector<Filme> filmes;
# };
# ```
#
# São as estruturas de dados utilizadas no código. A estrutura ``Filme`` armazena as informações de cada filme, como id, horário de início e fim e categoria. A estrutura ``Categoria`` armazena o id e a quantidade de filmes de cada categoria. A estrutura ``Maratona`` armazena a disponibilidade de horários da maratona e os filmes selecionados.
#
# #### Funções Auxiliares
#
# ```cpp
# std::bitset<24> gera_horario(int inicio, int fim) {
#     std::bitset<24> horario;
#
#     if (inicio == fim) {
#         horario.set(inicio);
#         return horario;
#     }
#
#     for (int i = inicio; i < fim; i++) {
#         horario.set(i);
#     }
#
#     return horario;
# }
#
# bool compara_filme(Filme a, Filme b) {
#     return a.fim < b.fim;
# }
# ```
#
# A função ``gera_horario`` recebe o horário de início e fim de um filme e retorna um std::bitset<24> com os bits correspondentes ao horário ocupado pelo filme. A função ``compara_filme`` é utilizada para ordenar os filmes de acordo com o horário de fim, em ordem crescente.
#
# #### Função Principal
#
# ```cpp
# int main() {
#     int n, m;
#     cin >> n >> m; // lê o número de filmes e de categorias
#     vector<Filme> filmes(n); // cria um vetor de filmes com tamanho n
#     vector<Categoria> categorias(m); // cria um vetor de categorias com tamanho m
#     Maratona maratona; // cria uma maratona
#
#     // Lê a quantidade de filmes de cada categoria
#     for (int i = 0; i < m; i++) {
#         cin >> categorias[i].quantidade;
#         categorias[i].id = i + 1;
#     }
#
#     // Lê as informações dos filmes
#     for (int i = 0; i < n; i++) {
#         int inicio, fim, categoria;
#         cin >> inicio >> fim >> categoria;
#
#         // Se o horário de início é maior que o horário de fim,
#         // significa que o filme se estende até o dia seguinte
#         if (inicio > fim) {
#             if (fim == 0) {
#                 fim = 24;
#             } else if (inicio == -1 || fim == -1) {
#                 continue; // Ignora filmes com horários inválidos
#             } else {
#                 continue; // Ignora filmes com horários inválidos
#             }
#         }
#
#         // Cria um filme com as informações lidas
#         Filme filme;
#         filme.id = i + 1;
#         filme.inicio = inicio;
#         filme.fim = fim;
#         filme.categoria = categoria;
#         filme.horario = gera_horario(inicio, fim);
#
#         // Adiciona o filme ao vetor de filmes
#         filmes.push_back(filme);
#     }
#
#     // Ordena os filmes por ordem crescente de horário de fim
#     sort(filmes.begin(), filmes.end(), compara_filme);
#
#     // Chama a função que implementa a heurística gulosa para encontrar a programação da maratona
#     heuristica_gulosa(filmes, categorias, maratona);
#
#     return 0;
# }
# ```
#
# #### Heurística Gulosa
#
# ```cpp
# void heuristica_gulosa(vector<Filme> &filmes, vector<Categoria> &categorias, Maratona &maratona) {
#     int maximo = 0;
#     int size_of_filmes = filmes.size();
#
#     for (int i = 0; i < size_of_filmes; i++) {
#         Filme filme = filmes[i];
#         int categoria = filme.categoria;
#         std::bitset<24> horario = filme.horario;
#
#         if (categorias[categoria - 1].quantidade == 0) {
#             continue;
#         }
#
#         if (maratona.disponibilidade == 0) {
#             maratona.disponibilidade = horario;
#             maratona.filmes.push_back(filme);
#             categorias[categoria - 1].quantidade--;
#             maximo++;
#         } else {
#             if ((maratona.disponibilidade & horario) == 0) {
#                 maratona.disponibilidade |= horario;
#                 maratona.filmes.push_back(filme);
#                 categorias[categoria - 1].quantidade--;
#                 maximo++;
#             }
#         }
#     }
#
#     cout << maximo << endl;
#
#     for (int i = 0; i < maximo; i++) {
#         cout << maratona.filmes[i].id << " " << maratona.filmes[i].inicio << " " << maratona.filmes[i].fim << " " << maratona.filmes[i].categoria << endl;
#     }
# }
# ```
#
# A função ``heuristica_gulosa`` implementa uma heurística gulosa para encontrar a maior quantidade possível de filmes em uma maratona de acordo com a disponibilidade e a categoria de cada filme.
#
# A função recebe três argumentos: ``filmes``, um vetor contendo todos os filmes a serem considerados na maratona; ``categorias``, um vetor de estrutura ``Categoria`` que contém informações sobre a quantidade de filmes que podem ser selecionados para cada categoria; e ``maratona``, uma estrutura que contém um vetor de filmes selecionados e uma ``bitset`` representando a disponibilidade de horários na maratona.
#
# A função começa definindo a variável ``maximo`` como 0, que será atualizada com a quantidade máxima de filmes selecionados para a maratona. Em seguida, um loop é executado para cada filme em ``filmes``.
#
# Para cada filme, a função verifica se a categoria desse filme já teve a quantidade máxima de filmes selecionados, caso tenha, o filme é pulado e o loop continua. Caso contrário, a função verifica se a disponibilidade de horários da maratona é 0 (ou seja, nenhum filme foi selecionado até agora). Se for esse o caso, a disponibilidade de horários é atualizada com a disponibilidade do horário do filme e o filme é adicionado ao vetor de filmes selecionados na maratona. A quantidade de filmes da categoria correspondente é decrementada e a variável ``maximo`` é incrementada.
#
# Caso a disponibilidade de horários da maratona já tenha sido definida, a função verifica se a disponibilidade do horário do filme selecionado não entra em conflito com a disponibilidade dos horários dos filmes já selecionados. Isso é feito usando a operação bit a bit "AND" entre as disponibilidades de horário do filme e da maratona. Se o resultado for 0, significa que os horários não entram em conflito e o filme pode ser adicionado. Caso contrário, o filme é pulado.
#
# Por fim, a função imprime o valor de ``maximo``, que representa a quantidade de filmes selecionados para a maratona, e imprime as informações dos filmes selecionados: seu id, horário de início e horário de fim.

# %% [markdown]
# ## Aleatoriedade
#
# O código da estratégia de Aleatorização se diferencia somente na função ``main`` e o uso da nova função ``aleatoriedade``.
#
# #### Função Principal
#
# ```cpp
# int main() {
#     int n, m;
#     cin >> n >> m; // Lê o número de filmes (n) e o número de categorias (m)
#
#     vector<Filme> filmes; // Vetor que armazenará os filmes
#     vector<Categoria> categorias(m); // Vetor que armazenará as categorias
#     Maratona maratona; // Objeto que representará a maratona
#
#     // Lê a quantidade de filmes para cada categoria e inicializa o id de cada categoria
#     for (int i = 0; i < m; i++) {
#         cin >> categorias[i].quantidade;
#         categorias[i].id = i + 1;
#     }
#
#     // Lê as informações dos filmes e gera a lista de filmes
#     for (int i = 0; i < n; i++) {
#         int inicio, fim, categoria;
#         cin >> inicio >> fim >> categoria;
#
#         // Trata casos em que o horário do filme é inválido
#         if (inicio > fim) {
#             if (fim == 0){
#                 fim = 24;
#             } else if (inicio == -1 || fim == -1) {
#                 continue;
#             } else {
#                 continue;
#             }
#         }
#
#         Filme filme;
#         filme.id = i + 1;
#         filme.inicio = inicio;
#         filme.fim = fim;
#         filme.categoria = categoria;
#         filme.horario = gera_horario(inicio, fim);
#
#         filmes.push_back(filme);
#     }
#
#     sort(filmes.begin(), filmes.end(), compara_filme); // Ordena os filmes por horário de término
#
#     int size_of_filmes = filmes.size();
#
#     map<int, vector<Filme>> filmes_por_horario; // Mapa que armazenará os filmes por horário
#
#     // Separa os filmes por horário de término
#     for (int i = 0; i < size_of_filmes; i++) {
#         filmes_por_horario[filmes[i].fim].push_back(filmes[i]);
#     }
#
#     // Realiza a escolha aleatória dos filmes para a maratona
#     aleatoriedade(categorias, maratona, filmes_por_horario);
#
#     return 0;
# }
# ```
#
# #### Aleatoriedade
#
# ```cpp
# void aleatoriedade(vector<Categoria> &categorias, Maratona &maratona, map<int, vector<Filme>> filmes_por_horario){
#     unsigned seed = std::chrono::system_clock::now().time_since_epoch().count();
#     std::default_random_engine generator (seed);
#     std::binomial_distribution<int> distribution (1, 0.75);
#     distribution(generator);
#
#     bitset<24> mochila_cheia(0xFFFFFF);
#
#     for (int i = 1; i <= 24; i++){
#         if (maratona.disponibilidade == mochila_cheia){
#             break;
#         }
#
#         if (filmes_por_horario[i].size() == 0){
#             continue;
#         }
#
#         Filme filme_escolhido;
#
#         srand(time(NULL));
#         if (distribution(generator)){
#             for (int j = 0; j < static_cast<int>(filmes_por_horario[i].size()); j++){
#                 if ((!(maratona.disponibilidade & filmes_por_horario[i][j].horario).any()) && (categorias[filmes_por_horario[i][j].categoria - 1].quantidade > 0)){
#                     filme_escolhido = filmes_por_horario[i][j];
#                     break;
#                 }
#
#                 filme_escolhido.id = -1;
#             }
#         } else {
#             vector<Filme> filmes_disponiveis_no_horario;
#
#             for (int j = 1; j < static_cast<int>(filmes_por_horario[i].size()); j++){
#                 if ((!(maratona.disponibilidade & filmes_por_horario[i][j].horario).any()) && (categorias[filmes_por_horario[i][j].categoria - 1].quantidade > 0)){
#                     filmes_disponiveis_no_horario.push_back(filmes_por_horario[i][j]);
#                 }
#             }
#
#             if (filmes_disponiveis_no_horario.size() == 0){
#                 continue;
#             }
#
#             filme_escolhido = filmes_disponiveis_no_horario[rand() % filmes_disponiveis_no_horario.size()];
#         }
#
#         if (filme_escolhido.id == -1){
#             continue;
#         }
#
#         maratona.disponibilidade |= filme_escolhido.horario;
#         maratona.filmes.push_back(filme_escolhido);
#         categorias[filme_escolhido.categoria - 1].quantidade--;
#     }
#
#     cout << maratona.filmes.size() << endl;
#
#     for (int i = 0; i < static_cast<int>(maratona.filmes.size()); i++){
#         cout << maratona.filmes[i].id << " " << maratona.filmes[i].inicio << " " << maratona.filmes[i].fim << " " << maratona.filmes[i].categoria << endl;
#     }
#
#     cout << endl;
# }
# ```
#
# A função ``aleatoriedade`` é responsável por gerar uma maratona aleatória de filmes que se encaixam dentro dos horários disponíveis e ainda respeitam a quantidade de filmes por categoria.
#
# Primeiramente, a função gera uma seed aleatória baseada no tempo atual para ser usada no gerador de números aleatórios. Em seguida, é criada uma distribuição binomial com probabilidade de sucesso de 0.75, que será usada para determinar se um filme disponível no horário será escolhido ou não.
#
# A partir daí, é feito um loop pelos 24 horários possíveis. Se a maratona já estiver cheia, o loop é interrompido. Se não houver filmes disponíveis no horário atual, o loop segue para o próximo horário.
#
#
# A função utiliza a distribuição binomial criada anteriormente para escolher qual método de escolha será utilizado. Se o número aleatório gerado for 0, a função escolhe um filme aleatório dentre os disponíveis no horário atual. Caso contrário, a função escolhe o filme com o menor horário de término dentre os disponíveis no horário atual.
#
# Ele antes verifica se algum filme foi selecionado.
#
# Após isso, ele é adicionado à lista de filmes da maratona. A quantidade de filmes da sua categoria é reduzida em 1. A disponibilidade de horários da maratona é atualizada com a disponibilidade do filme selecionado.
#
# Por fim, a função imprime a quantidade de filmes na maratona, seguida da lista de filmes, com seus respectivos IDs, horários de início e fim e categoria.

# %% [markdown]
# ### Paralelismo com OpenMP
#
# Abaixo, a explicação por partes principais do código:
#
# #### Bibliotecas
#
# ```cpp
# #include <iostream>
# #include <vector>
# #include <algorithm>
# #include <iomanip>
# #include <bitset>
#
# #include <cmath>
# #include <stack>
# #include <omp.h>
# ```
#
# São as bibliotecas padrões da linguagem C++. `iostream` é para entrada e saída de dados, ``vector`` é para armazenar listas de objetos, ``algorithm`` é para algoritmos de ordenação e outras operações em contêineres, ``iomanip`` é para manipulação de fluxos de saída e ``bitset`` é para manipulação de bits. ``cmath`` é para funções matemáticas, ``stack`` é para pilhas e ``omp.h`` é para paralelismo com OpenMP.
#
# #### Estruturas de Dados
#
# ```cpp
# struct Filme {
#     int id;
#     int inicio;
#     int fim;
#     int categoria;
#     std::bitset<24> horario;
# };
#
# struct Categoria {
#     int id;
#     int quantidade;
# };
#
# struct Maratona {
#     std::bitset<24> disponibilidade;
#     std::vector<Filme> filmes;
# };
# ```
#
# São as estruturas de dados utilizadas no código. A estrutura ``Filme`` armazena as informações de cada filme, como id, horário de início e fim e categoria. A estrutura ``Categoria`` armazena o id e a quantidade de filmes de cada categoria. A estrutura ``Maratona`` armazena a disponibilidade de horários da maratona e os filmes selecionados.
#
# #### Funções Auxiliares
#
# ```cpp
# std::bitset<24> gera_horario(int inicio, int fim) {
#     std::bitset<24> horario;
#
#     if (inicio == fim) {
#         horario.set(inicio);
#         return horario;
#     }
#
#     for (int i = inicio; i < fim; i++) {
#         horario.set(i);
#     }
#
#     return horario;
# }
# ```
#
# A função ``gera_horario`` recebe o horário de início e fim de um filme e retorna um std::bitset<24> com os bits correspondentes ao horário ocupado pelo filme.
#
# #### Função Principal
#
# ```cpp
# int main() {
#     int n, m;
#     cin >> n >> m; // lê o número de filmes e de categorias
#     vector<Filme> filmes(n); // cria um vetor de filmes com tamanho n
#     vector<Categoria> categorias(m); // cria um vetor de categorias com tamanho m
#     Maratona maratona; // cria uma maratona
#
#     // Lê a quantidade de filmes de cada categoria
#     for (int i = 0; i < m; i++) {
#         cin >> categorias[i].quantidade;
#         categorias[i].id = i + 1;
#     }
#
#     // Lê as informações dos filmes
#     for (int i = 0; i < n; i++) {
#         int inicio, fim, categoria;
#         cin >> inicio >> fim >> categoria;
#
#         // Se o horário de início é maior que o horário de fim,
#         // significa que o filme se estende até o dia seguinte
#         if (inicio > fim) {
#             if (fim == 0) {
#                 fim = 24;
#             } else if (inicio == -1 || fim == -1) {
#                 continue; // Ignora filmes com horários inválidos
#             } else {
#                 continue; // Ignora filmes com horários inválidos
#             }
#         }
#
#         // Cria um filme com as informações lidas
#         Filme filme;
#         filme.id = i + 1;
#         filme.inicio = inicio;
#         filme.fim = fim;
#         filme.categoria = categoria;
#         filme.horario = gera_horario(inicio, fim);
#
#         // Adiciona o filme ao vetor de filmes
#         filmes.push_back(filme);
#     }
#
#     // Chamada da função de busca exaustiva
#     busca_exaustiva(filmes, categorias, maratona);
#
#     return 0;
# }
# ```
#
# #### Busca Exaustiva
#
# ```cpp
# void busca_exaustiva(vector<Filme> &filmes, vector<Categoria> &categorias, Maratona &maratona)
# {
#     int maximo = 0;
#     int size_of_filmes = filmes.size();
#     cout << "Quantidade total de filmes: " << size_of_filmes << endl;
#
#     long int todas_combinacoes = pow(2, size_of_filmes);
#     cout << "Quantidade total de combinações: " << todas_combinacoes << endl;
#     long int i;
#
# #pragma omp parallel for
#     for (i = 0; i < todas_combinacoes; i++)
#     {
#         int num_films = 0;
#         vector<int> categorias_vistas(categorias.size(), 0);
#         stack<Filme> filmes_vistos;
#         Maratona maratona_atual;
#
#         bitset<64> filmes_vector(i);
#         bitset<64> aux = filmes_vector;
#
#         for (int j = 0; j < size_of_filmes; j++)
#         {
#             if (aux[j] == 1)
#             {
#                 if ((maratona_atual.disponibilidade & filmes[j].horario) == 0)
#                 {
#                     num_films++;
#                     filmes_vistos.push(filmes[j]);
#                     maratona_atual.disponibilidade |= filmes[j].horario;
#                     categorias_vistas[filmes[j].categoria - 1]++;
#                 }
#
#                 aux[j] = 0;
#             }
#         }
#
# #pragma omp critical
#         if (num_films > maximo)
#         {
#             maximo = num_films;
#             maratona.filmes.clear();
#             maratona.disponibilidade.reset();
#
#             while (!filmes_vistos.empty())
#             {
#                 Filme filme = filmes_vistos.top();
#                 filmes_vistos.pop();
#                 maratona.filmes.push_back(filme);
#                 maratona.disponibilidade |= filme.horario;
#             }
#         }
#     }
#
#     cout << "Quantidade máxima possível: " << maximo << endl;
#
#     for (int i = 0; i < maximo; i++)
#     {
#         cout << "Filme: [" << maratona.filmes[i].id << "] " << maratona.filmes[i].inicio << " " << maratona.filmes[i].fim << " " << maratona.filmes[i].categoria << endl;
#     }
# }
# ```
#
# A função ``busca_exaustiva`` é responsável por realizar a busca exaustiva para encontrar a melhor combinação de filmes em uma maratona. Vamos analisar passo a passo o que essa função faz:
#
# 1. A função recebe como parâmetros um vetor de filmes (``filmes``), um vetor de categorias (``categorias``) e um objeto Maratona vazio (``maratona``).
#
# 2. É declarada uma variável ``maximo`` para armazenar o número máximo de filmes que podem ser incluídos na maratona.
#
# 3. O tamanho do vetor ``filmes`` é armazenado na variável ``size_of_filmes``.
#
# 4. É exibida na tela a quantidade total de filmes.
#
# 5. É calculado o número total de combinações possíveis usando a fórmula 2^N, onde N é o número de filmes. Essa quantidade é armazenada na variável ``todas_combinacoes``.
#
# 6. É exibida na tela a quantidade total de combinações.
#
# 7. Inicia-se um loop paralelo usando a diretiva ``#pragma omp parallel for``, que itera sobre todas as combinações possíveis.
#
# 8. Dentro do loop, são declaradas variáveis locais para contar o número de filmes selecionados (``num_films``), um vetor para registrar quantas categorias foram vistas (``categorias_vistas``), uma pilha de filmes selecionados (``filmes_vistos``) e um objeto Maratona temporário (``maratona_atual``).
#
# 9. Um objeto ``bitset`` chamado ``filmes_vector`` é criado a partir do número da iteração atual (``i``). Esse bitset é utilizado para determinar quais filmes serão selecionados na combinação atual.
#
# 10. Um loop ``for`` itera sobre os filmes do vetor ``filmes``.
#
# 11. Dentro do loop, é verificado se o bit correspondente em ``filmes_vector`` é igual a 1. Se for, significa que esse filme deve ser selecionado.
#
# 12. É verificado se o horário do filme não conflita com os filmes já selecionados na maratona atual. Isso é feito comparando o bitset de horário do filme com o bitset de disponibilidade da maratona atual (``maratona_atual.disponibilidade``). Se não houver conflito, o filme é considerado válido.
#
# 13. Se o filme for válido, incrementa-se o número de filmes selecionados (``num_films``), adiciona-se o filme à pilha ``filmes_vistos``, atualiza-se o bitset de disponibilidade da maratona atual e registra-se que uma categoria foi vista incrementando o valor correspondente no vetor ``categorias_vistas``.
#
# 14. O bit correspondente em ``aux`` é setado como 0, indicando que esse filme já foi selecionado.
#
# 15. Após o loop, é verificado se o número de filmes selecionados (``num_films``) é maior que o número máximo encontrado até o momento (``maximo``). Se for, significa que essa combinação de filmes é a melhor até agora, então o número máximo é atualizado, e as informações da maratona atual são copiadas para o objeto ``maratona``.
#
# 16. Após o loop paralelo, o número máximo possível de filmes é exibido na tela.
#
# 17. É exibida na tela a lista de filmes selecionados na maratona, com o ID, horário de início, horário de fim e categoria de cada filme.
#
# Essa função utiliza paralelismo para acelerar a busca exaustiva, dividindo as combinações entre diferentes threads. Cada thread avalia uma parte das combinações e, ao final, o resultado é combinado para obter a melhor maratona possível.

# %% [markdown]
# ### Paralelismo com GPU
#
# Abaixo, a explicação por partes principais do código:
#
# #### Bibliotecas
#
# ```cpp
# #include <iostream>
# #include <vector>
#
# #include <thrust/host_vector.h>
# #include <thrust/sequence.h>
# #include <thrust/device_vector.h>
# #include <thrust/functional.h>
# #include <thrust/copy.h>
# ```
#
# - ``<iostream>``: Fornece recursos para entrada e saída de dados no console.
# - ``<vector>``: Fornece a classe de vetor para manipulação de sequências dinâmicas.
# - ``<thrust/host_vector.h>``: Fornece a classe host_vector do Thrust, que representa um vetor hospedado na memória do sistema.
# - ``<thrust/sequence.h>``: Fornece a função sequence do Thrust, que preenche um intervalo com uma sequência de valores.
# - ``<thrust/device_vector.h>``: Fornece a classe device_vector do Thrust, que representa um vetor hospedado na memória da GPU.
# - ``<thrust/functional.h>``: Fornece funções e operadores funcionais para serem usados com algoritmos do Thrust.
# - ``<thrust/copy.h>``: Fornece a função copy do Thrust, que copia elementos de uma sequência de origem para uma sequência de destino.
#
# #### Estruturas de Dados
#
# ```cpp
# struct Filme
# {
#   int id;
#   int inicio;
#   int fim;
#   int categoria;
# };
# ```
#
# A estrutura ``Filme`` armazena as informações de cada filme, como id, horário de início e fim e categoria.
#
# #### Funções Auxiliares
#
# ```cpp
# void preenche_horarios(int &horarios_disponiveis, int inicio, int fim)
# {
#   for (int i = inicio; i < fim; i++)
#   {
#     horarios_disponiveis |= (1 << i);
#   }
# }
# ```
#
# A função ``preenche_horarios`` Preenche um valor inteiro com os bits correspondentes aos horários disponíveis para um filme, com base nos horários de início e término fornecidos.
#
# #### Função Principal
#
# ```cpp
# int main()
# {
#   int n, m;
#   cin >> n >> m;
#
#   // Declaração das variáveis e containers utilizados no programa
#   vector<Filme> vetor_filmes;
#   thrust::host_vector<int> disponibilidade_categoria(m);
#
#   // Leitura da disponibilidade de cada categoria
#   for (int i = 0; i < m; i++)
#   {
#     cin >> disponibilidade_categoria[i];
#   }
#
#   // Leitura dos dados dos filmes
#   for (int i = 0; i < n; i++)
#   {
#     int inicio, fim, categoria;
#     cin >> inicio >> fim >> categoria;
#
#     // Tratamento especial para casos em que o início é maior que o fim
#     if (inicio > fim)
#     {
#       if (fim == 0)
#       {
#         fim = 24;
#       }
#       else if (inicio == -1 || fim == -1)
#       {
#         continue;
#       }
#       else
#       {
#         continue;
#       }
#     }
#
#     // Criação de um objeto Filme e adição ao vetor_filmes
#     Filme filme;
#     filme.id = i + 1;
#     filme.inicio = inicio;
#     filme.fim = fim;
#     filme.categoria = categoria;
#
#     vetor_filmes.push_back(filme);
#   }
#
#   int n_filmes = vetor_filmes.size();
#
#   // Criação de vetores host para armazenar os dados dos filmes
#   thrust::host_vector<int> categoria_filmes(n_filmes);
#   thrust::host_vector<int> horarios_filmes_cpu(n_filmes);
#
#   // Preenchimento dos vetores de horários e categorias dos filmes
#   for (int i = 0; i < n_filmes; i++)
#   {
#     horarios_filmes_cpu[i] = 0;
#     preenche_horarios(horarios_filmes_cpu[i],
#                       vetor_filmes[i].inicio,
#                       vetor_filmes[i].fim);
#     categoria_filmes[i] = vetor_filmes[i].categoria;
#   }
#
#   // Criação de vetores device para armazenar os dados dos filmes
#   thrust::device_vector<int> vetor_possibilidades_gpu(pow(2, n_filmes));
#
#   // Preenchimento do vetor de possibilidades com valores sequenciais
#   thrust::sequence(vetor_possibilidades_gpu.begin(), vetor_possibilidades_gpu.end());
#
#   thrust::device_vector<int> disponibilidade_categoria_gpu(disponibilidade_categoria);
#   thrust::device_vector<int> horarios_filmes_gpu(horarios_filmes_cpu);
#   thrust::device_vector<int> categoria_filmes_gpu(categoria_filmes);
#
#   // Execução do kernel de busca exaustiva na GPU
#   thrust::transform(
#       vetor_possibilidades_gpu.begin(),
#       vetor_possibilidades_gpu.end(),
#       vetor_possibilidades_gpu.begin(),
#       busca_exaustiva_gpu(n_filmes,
#                           m,
#                           raw_pointer_cast(disponibilidade_categoria_gpu.data()),
#                           raw_pointer_cast(horarios_filmes_gpu.data()),
#                           raw_pointer_cast(categoria_filmes_gpu.data())));
#
#   // Copia do resultado da GPU para a CPU
#   thrust::host_vector<int> config_vector_cpu_final = vetor_possibilidades_gpu;
#
#   // Encontra o valor máximo no vetor de configurações
#   int max_count = *thrust::max_element(config_vector_cpu_final.begin(), config_vector_cpu_final.end());
#
#   cout << max_count << endl;
#
#   int max_config = -1;
#   for (int i = 0; i < config_vector_cpu_final.size(); i++)
#   {
#     // Encontra a primeira configuração que possui o valor máximo
#     if (config_vector_cpu_final[i] == max_count)
#     {
#       max_config = i;
#       break;
#     }
#   }
#
#   // Imprime os filmes da configuração com o valor máximo
#   for (int i = 0; i < n_filmes; i++)
#   {
#     if (max_config & (1 << i))
#     {
#       cout << vetor_filmes[i].id << " " << vetor_filmes[i].inicio << " " << vetor_filmes[i].fim << " " << vetor_filmes[i].categoria << endl;
#     }
#   }
#
#   return 0;
# }
# ```
#
# #### Busca Exaustiva em GPU
#
# ```cpp
# struct busca_exaustiva_gpu
# {
#   int n_filmes;  // Número de filmes
#   int m_categorias;  // Número de categorias
#
#   int *disponibilidade_categoria;  // Ponteiro para o array de disponibilidade de categorias
#   int *horarios_filmes;  // Ponteiro para o array de horários dos filmes
#   int *categoria_filmes;  // Ponteiro para o array de categorias dos filmes
#
#   busca_exaustiva_gpu(int n_filmes_,
#                       int m_categorias_,
#                       int *disponibilidade_categoria_,
#                       int *horarios_filmes_,
#                       int *categoria_filmes_)
#       : n_filmes(n_filmes_),
#         m_categorias(m_categorias_),
#         disponibilidade_categoria(disponibilidade_categoria_),
#         horarios_filmes(horarios_filmes_),
#         categoria_filmes(categoria_filmes_)
#   {
#   }
#
#   __device__ int operator()(const int &config)
#   {
#     int horarios_disponiveis = 0;  // Variável para acompanhar os horários disponíveis
#     int categorias_vistas[16];  // Array para acompanhar as categorias vistas
#
#     // Inicializa o array de categorias vistas com os valores de disponibilidade_categoria
#     for (int i = 0; i < m_categorias; i++)
#     {
#       categorias_vistas[i] = disponibilidade_categoria[i];
#     }
#
#     int num_filmes = 0;  // Contador de filmes selecionados
#     for (int i = 0; i < n_filmes; i++)
#     {
#       if (config & (1 << i))
#       {
#         // Verifica se a categoria do filme está disponível
#         if (categorias_vistas[categoria_filmes[i] - 1] > 0)
#         {
#           // Verifica se há conflito de horários com filmes já selecionados
#           int horario_analisado = horarios_disponiveis & horarios_filmes[i];
#           if (horario_analisado != 0)
#             return false;  // Retorna falso se houver conflito de horários
#
#           categorias_vistas[categoria_filmes[i] - 1]--;  // Decrementa a contagem de categorias vistas
#           horarios_disponiveis |= horarios_filmes[i];  // Atualiza os horários disponíveis
#           num_filmes++;  // Incrementa o contador de filmes selecionados
#         }
#       }
#     }
#
#     return num_filmes;  // Retorna o número de filmes selecionados
#   }
# };
# ```
#
# - ``struct busca_exaustiva_gpu``: Sobrecarrega o operador de função ``()`` para criar um objeto função que será usado na transformação do Thrust. Essa estrutura contém os seguintes atributos:
# - ``n_filmes``: Número de filmes.
# - ``m_categorias``: Número de categorias.
# - ``disponibilidade_categoria``: Vetor de disponibilidade de categorias.
# - ``horarios_filmes``: Vetor de horários dos filmes.
# - ``categoria_filmes``: Vetor de categorias dos filmes.
# - O operador de função ``()`` realiza a busca exaustiva em uma configuração específica de filmes, verificando as restrições de disponibilidade de horários e categorias. Retorna o número de filmes assistidos se a configuração for válida, caso contrário, retorna falso.

# %% [markdown]
# ## Arquivo Output
#
# O arquivo de saída é gerado pelo programa e contém a:
#
# - Quantidade de filmes na maratona
# - Lista de filmes, com seus respectivos:
#     - IDs
#     - Horário de início
#     - Horário de fim
#     - Categoria
#
# Exemplo de arquivo de saída:
#
# ```
# 20
# 474 0 1 20
# 99 1 2 70
# 184 2 4 12
# 581 4 5 52
# 92 5 6 9
# 849 6 7 18
# 746 7 8 33
# 319 8 9 3
# 179 9 10 74
# 207 10 11 57
# 757 11 12 18
# 618 13 13 17
# 628 14 15 36
# 358 16 16 87
# 351 17 18 35
# 304 18 19 87
# 794 19 20 44
# 51 20 21 54
# 360 22 22 37
# 541 23 24 39
# ```
#
# Desta forma, é possível facilmente pegar os dados de saída e gerar um arquivo de texto com a lista de filmes da maratona e, com isso, gerar gráficos a partir dos dados, como veremos mais a frente.

# %% [markdown]
# ## Valgrind

# %% [markdown]
# Utilizando a ferramenta Valgrind, é possível analisar o programa e verificar se ele possui algum erro de memória. Além disso, é possível observar possíveis otimizações no código que podem ser feitas para melhorar a performance do programa.
#
# Para o contexto deste Projeto, utilizaremos esta ferramenta para comparar a performace de cada estratégia de geração de maratonas.
#
# Antes de continuar, é importante instalar a ferramenta Valgrind. Para isso, basta executar o seguinte comando no terminal:

# %%
# !sudo apt-get install valgrind
# Out:
# [sudo] password for user:

# %% [markdown]
# ### Heurística Gulosa

# %%
# !valgrind --tool=callgrind --vgdb=no ./gulosa < inputs/input-10k.txt  > gulosa_output_valgrind.txt
# Out:
# ==945824== Callgrind, a call-graph generating cache profiler
# ==945824== Copyright (C) 2002-2017, and GNU GPL'd, by Josef Weidendorfer et al.
# ==945824== Using Valgrind-3.15.0 and LibVEX; rerun with -h for copyright info
# ==945824== Command: ./gulosa
# ==945824==
# ==945824== For interactive control, run 'callgrind_control -h'.
# ==945824==
# ==945824== Events    : Ir
# ==945824== Collected : 44971779
# ==945824==
# ==945824== I   refs:      44,971,779

# %%
# !callgrind_annotate callgrind.out.945824 gulosa.cpp

# %% [markdown]
# ```txt
# --------------------------------------------------------------------------------
# Profile data file 'callgrind.out.945824' (creator: callgrind-3.15.0)
# --------------------------------------------------------------------------------
# I1 cache:
# D1 cache:
# LL cache:
# Timerange: Basic block 0 - 9240846
# Trigger: Program termination
# Profiled target:  ./gulosa (PID 945824, part 1)
# Events recorded:  Ir
# Events shown:     Ir
# Event sort order: Ir
# Thresholds:       99
# Include dirs:
# User annotated:   gulosa.cpp
# Auto-annotation:  off
#
# --------------------------------------------------------------------------------
# Ir
# --------------------------------------------------------------------------------
# 44,971,779  PROGRAM TOTALS
#
# --------------------------------------------------------------------------------
# Ir         file:function
# --------------------------------------------------------------------------------
# 8,078,213  ???:std::istreambuf_iterator<char, std::char_traits<char> > std::num_get<char, std::istreambuf_iterator<char, std::char_traits<char> > >::_M_extract_int<long>(std::istreambuf_iterator<char, std::char_traits<char> >, std::istreambuf_iterator<char, std::char_traits<char> >, std::ios_base&, std::_Ios_Iostate&, long&) const [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
# 5,462,182  /build/glibc-SzIz7B/glibc-2.31/libio/getc.c:getc [/usr/lib/x86_64-linux-gnu/libc-2.31.so]
# 4,225,106  /build/glibc-SzIz7B/glibc-2.31/libio/genops.c:_IO_sputbackc [/usr/lib/x86_64-linux-gnu/libc-2.31.so]
# 3,557,984  /build/glibc-SzIz7B/glibc-2.31/libio/ioungetc.c:ungetc [/usr/lib/x86_64-linux-gnu/libc-2.31.so]
# 2,528,568  ???:std::istream::sentry::sentry(std::istream&, bool) [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
# 2,001,366  ???:__gnu_cxx::stdio_sync_filebuf<char, std::char_traits<char> >::underflow() [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
# 1,695,186  /usr/include/c++/9/bits/predefined_ops.h:void std::__introsort_loop<__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)> >(__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)>)'2
# 1,655,610  ???:std::istream::operator>>(int&) [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
# 1,327,630  /usr/include/c++/9/bits/move.h:void std::__introsort_loop<__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)> >(__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)>)'2
# 1,211,735  gulosa.cpp:compara_filme(Filme, Filme) [/home/user/log-comp-davirvs/supercomputacao/projetos/maratona-filmes/gulosa]
# 1,173,978  ???:0x0000000000126e50 [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
# 1,047,080  /build/glibc-SzIz7B/glibc-2.31/elf/dl-lookup.c:_dl_lookup_symbol_x [/usr/lib/x86_64-linux-gnu/ld-2.31.so]
# 1,032,102  /usr/include/c++/9/bits/stl_algo.h:void std::__introsort_loop<__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)> >(__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)>)'2 [/home/user/log-comp-davirvs/supercomputacao/projetos/maratona-filmes/gulosa]
#   964,256  /build/glibc-SzIz7B/glibc-2.31/libio/iofflush.c:fflush [/usr/lib/x86_64-linux-gnu/libc-2.31.so]
#   664,378  ???:0x0000000000125250 [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
#   648,680  ???:__gnu_cxx::stdio_sync_filebuf<char, std::char_traits<char> >::uflow() [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
#   606,923  ???:0x00000000048e9130 [???]
#   572,527  /build/glibc-SzIz7B/glibc-2.31/libio/libioP.h:fflush
#   563,233  /build/glibc-SzIz7B/glibc-2.31/elf/dl-lookup.c:do_lookup_x [/usr/lib/x86_64-linux-gnu/ld-2.31.so]
#   542,688  /build/glibc-SzIz7B/glibc-2.31/libio/fileops.c:_IO_file_sync@@GLIBC_2.2.5 [/usr/lib/x86_64-linux-gnu/libc-2.31.so]
#   541,836  ???:0x0000000000126f00 [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
#   451,950  ???:std::ostream::flush() [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
#   444,753  ???:0x00000000048e6880 [???]
#   304,196  gulosa.cpp:heuristica_gulosa(std::vector<Filme, std::allocator<Filme> >&, std::vector<Categoria, std::allocator<Categoria> >&, Maratona&) [/home/user/log-comp-davirvs/supercomputacao/projetos/maratona-filmes/gulosa]
#   274,548  /build/glibc-SzIz7B/glibc-2.31/elf/../sysdeps/x86_64/dl-machine.h:_dl_relocate_object
#   270,802  /usr/include/c++/9/bits/predefined_ops.h:void std::__introsort_loop<__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)> >(__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)>)
#   269,683  /usr/include/c++/9/bits/stl_algo.h:main
#   228,053  gulosa.cpp:main [/home/user/log-comp-davirvs/supercomputacao/projetos/maratona-filmes/gulosa]
#   197,806  /usr/include/c++/9/bitset:gera_horario(int, int)
#   182,238  ???:std::locale::id::_M_id() const [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
#   179,802  /usr/include/c++/9/bits/move.h:void std::__introsort_loop<__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)> >(__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)>)
#   175,392  /usr/include/c++/9/bits/predefined_ops.h:main
#   162,635  gulosa.cpp:gera_horario(int, int) [/home/user/log-comp-davirvs/supercomputacao/projetos/maratona-filmes/gulosa]
#   146,579  /usr/include/c++/9/bits/stl_algo.h:void std::__introsort_loop<__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)> >(__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)>) [/home/user/log-comp-davirvs/supercomputacao/projetos/maratona-filmes/gulosa]
#   118,149  /build/glibc-SzIz7B/glibc-2.31/elf/dl-lookup.c:check_match [/usr/lib/x86_64-linux-gnu/ld-2.31.so]
#    90,419  /build/glibc-SzIz7B/glibc-2.31/elf/do-rel.h:_dl_relocate_object
#    90,390  ???:__gnu_cxx::stdio_sync_filebuf<char, std::char_traits<char> >::sync() [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
#    83,011  /build/glibc-SzIz7B/glibc-2.31/string/../sysdeps/x86_64/strcmp.S:strcmp [/usr/lib/x86_64-linux-gnu/ld-2.31.so]
#    72,727  /usr/include/c++/9/bits/stl_vector.h:main
#    71,545  /build/glibc-SzIz7B/glibc-2.31/elf/dl-addr.c:_dl_addr [/usr/lib/x86_64-linux-gnu/libc-2.31.so]
#    70,287  /usr/include/c++/9/bits/stl_uninitialized.h:void std::vector<Filme, std::allocator<Filme> >::_M_realloc_insert<Filme const&>(__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, Filme const&)
#    60,623  ???:0x00000000048e64f0 [???]
#    60,271  ???:0x00000000048e9080 [???]
#    60,266  /build/glibc-SzIz7B/glibc-2.31/libio/../sysdeps/unix/sysv/linux/x86/lowlevellock.h:fflush
#    60,215  ???:0x00000000048e7530 [???]
#    60,209  ???:0x00000000048e6f30 [???]
#    60,209  ???:0x00000000048e86a0 [???]
#    60,204  ???:0x0000000000109170 [???]
#    60,204  ???:std::num_get<char, std::istreambuf_iterator<char, std::char_traits<char> > >::do_get(std::istreambuf_iterator<char, std::char_traits<char> >, std::istreambuf_iterator<char, std::char_traits<char> >, std::ios_base&, std::_Ios_Iostate&, long&) const [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
#    46,879  /usr/include/c++/9/bits/stl_algo.h:void std::__move_median_to_first<__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)> >(__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)>) [/home/user/log-comp-davirvs/supercomputacao/projetos/maratona-filmes/gulosa]
#    40,001  /usr/include/c++/9/bits/stl_uninitialized.h:main
#
# --------------------------------------------------------------------------------
# -- User-annotated source: gulosa.cpp
# --------------------------------------------------------------------------------
# Ir
#
# -- line 19 ----------------------------------------
#       .      int quantidade;
#       .  };
#       .
#       .  struct Maratona {
#       .      std::bitset<24> disponibilidade;
#       .      std::vector<Filme> filmes;
#       .  };
#       .
# 242,347  bool compara_filme(Filme a, Filme b) {
# 727,041      return a.fim < b.fim;
# 242,347  }
#       .
#  18,172  std::bitset<24> gera_horario(int inicio, int fim) {
#  18,042      std::bitset<24> horario;
#       .
#  18,172      if (inicio == fim) {
#      65          horario.set(inicio);
#     195          return horario;
#       .      }
#       .
#  62,885      for (int i = inicio; i < fim; i++) {
#  26,932          horario.set(i);
#       .      }
#       .
#       .      return horario;
#  18,172  }
#       .
#      13  void heuristica_gulosa(vector<Filme> &filmes, vector<Categoria> &categorias, Maratona &maratona) {
#       1      int maximo = 0;
#       1      int size_of_filmes = filmes.size();
#       .
#  76,326      for (int i = 0; i < size_of_filmes; i++) {
#  76,344          Filme filme = filmes[i];
#       .          int categoria = filme.categoria;
#       .          std::bitset<24> horario = filme.horario;
#       .
# 114,516          if (categorias[categoria - 1].quantidade == 0) {
#       .              continue;
#       .          }
#       .
#  18,172          if (maratona.disponibilidade == 0) {
#       .              maratona.disponibilidade = horario;
#       .              maratona.filmes.push_back(filme);
#       .              categorias[categoria - 1].quantidade--;
#       .              maximo++;
#       .          } else {
#  18,170              if ((maratona.disponibilidade & horario) == 0) {
#       .                  maratona.disponibilidade |= horario;
#       6                  maratona.filmes.push_back(filme);
#      72                  categorias[categoria - 1].quantidade--;
#      24                  maximo++;
#       .              }
#       .          }
#       .      }
#       .
#       4      cout << maximo << endl;
#   7,298  => ???:0x0000000000109240 (1x)
#       .
#      56      for (int i = 0; i < maximo; i++) {
#     480          cout << maratona.filmes[i].id << " " << maratona.filmes[i].inicio << " " << maratona.filmes[i].fim << " " << maratona.filmes[i].categoria << endl;
#  40,037  => ???:0x0000000000109240 (96x)
#       .      }
#      11  }
#       .
#      11  int main() {
#       .      int n, m;
#       6      cin >> n >> m;
#   9,051  => ???:0x0000000000109170 (2x)
#       1      vector<Filme> filmes(n);
#       1      vector<Categoria> categorias(m);
#       .      Maratona maratona;
#       .
#     305      for (int i = 0; i < m; i++) {
#     301          cin >> categorias[i].quantidade;
# 121,283  => ???:0x0000000000109170 (100x)
#     300          categorias[i].id = i + 1;
#       .      }
#       .
#  20,005      for (int i = 0; i < n; i++) {
#       .          int inicio, fim, categoria;
#  90,001          cin >> inicio >> fim >> categoria;
# 34,747,066  => ???:0x0000000000109170 (30,000x)
#       .
#  50,000          if (inicio > fim) {
#   2,666              if (fim == 0){
#     838                  fim = 24;
#       .              } else if (inicio == -1 || fim == -1) {
#       .                  continue;
#       .              } else {
#       .                  continue;
#       .              }
#       .          }
#       .
#       .          Filme filme;
#   9,086          filme.id = i + 1;
#   9,086          filme.inicio = inicio;
#   9,086          filme.fim = fim;
#  18,172          filme.categoria = categoria;
#  18,172          filme.horario = gera_horario(inicio, fim);
# 360,441  => gulosa.cpp:gera_horario(int, int) (9,086x)
#       .
#       .          filmes.push_back(filme);
#       .      }
#       .
#       .      sort(filmes.begin(), filmes.end(), compara_filme);
#       .
#       4      heuristica_gulosa(filmes, categorias, maratona);
# 427,127  => gulosa.cpp:heuristica_gulosa(std::vector<Filme, std::allocator<Filme> >&, std::vector<Categoria, std::allocator<Categoria> >&, Maratona&) (1x)
#       .
#       .      return 0;
#       .
#      15  }
#
# --------------------------------------------------------------------------------
# Ir
# --------------------------------------------------------------------------------
# 1,906,622  events annotated
# ```

# %% [markdown]
# ### Aleatoriedade

# %%
# !valgrind --tool=callgrind --vgdb=no ./aleatoriedade < inputs/input-10k.txt  > aleatoriedade_output_valgrind.txt
# Out:
# ==956164== Callgrind, a call-graph generating cache profiler
# ==956164== Copyright (C) 2002-2017, and GNU GPL'd, by Josef Weidendorfer et al.
# ==956164== Using Valgrind-3.15.0 and LibVEX; rerun with -h for copyright info
# ==956164== Command: ./aleatoriedade
# ==956164==
# ==956164== For interactive control, run 'callgrind_control -h'.
# ==956164==
# ==956164== Events    : Ir
# ==956164== Collected : 42245947
# ==956164==
# ==956164== I   refs:      42,245,947

# %%
# !callgrind_annotate callgrind.out.956164 aleatoriedade.cpp

# %% [markdown]
# ```txt
# --------------------------------------------------------------------------------
# Profile data file 'callgrind.out.956164' (creator: callgrind-3.15.0)
# --------------------------------------------------------------------------------
# I1 cache:
# D1 cache:
# LL cache:
# Timerange: Basic block 0 - 8990130
# Trigger: Program termination
# Profiled target:  ./aleatoriedade (PID 956164, part 1)
# Events recorded:  Ir
# Events shown:     Ir
# Event sort order: Ir
# Thresholds:       99
# Include dirs:
# User annotated:   aleatoriedade.cpp
# Auto-annotation:  off
#
# --------------------------------------------------------------------------------
# Ir
# --------------------------------------------------------------------------------
# 42,245,947  PROGRAM TOTALS
#
# --------------------------------------------------------------------------------
# Ir         file:function
# --------------------------------------------------------------------------------
# 8,078,213  ???:std::istreambuf_iterator<char, std::char_traits<char> > std::num_get<char, std::istreambuf_iterator<char, std::char_traits<char> > >::_M_extract_int<long>(std::istreambuf_iterator<char, std::char_traits<char> >, std::istreambuf_iterator<char, std::char_traits<char> >, std::ios_base&, std::_Ios_Iostate&, long&) const [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
# 5,462,182  /build/glibc-SzIz7B/glibc-2.31/libio/getc.c:getc [/usr/lib/x86_64-linux-gnu/libc-2.31.so]
# 4,225,106  /build/glibc-SzIz7B/glibc-2.31/libio/genops.c:_IO_sputbackc [/usr/lib/x86_64-linux-gnu/libc-2.31.so]
# 3,557,984  /build/glibc-SzIz7B/glibc-2.31/libio/ioungetc.c:ungetc [/usr/lib/x86_64-linux-gnu/libc-2.31.so]
# 2,528,568  ???:std::istream::sentry::sentry(std::istream&, bool) [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
# 2,001,366  ???:__gnu_cxx::stdio_sync_filebuf<char, std::char_traits<char> >::underflow() [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
# 1,655,610  ???:std::istream::operator>>(int&) [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
# 1,173,978  ???:0x0000000000126e50 [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
# 1,052,479  /build/glibc-SzIz7B/glibc-2.31/elf/dl-lookup.c:_dl_lookup_symbol_x [/usr/lib/x86_64-linux-gnu/ld-2.31.so]
#   964,224  /build/glibc-SzIz7B/glibc-2.31/libio/iofflush.c:fflush [/usr/lib/x86_64-linux-gnu/libc-2.31.so]
#   664,202  ???:0x0000000000125250 [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
#   661,862  /usr/include/c++/9/bits/predefined_ops.h:void std::__introsort_loop<__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)> >(__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)>)'2
#   648,680  ???:__gnu_cxx::stdio_sync_filebuf<char, std::char_traits<char> >::uflow() [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
#   606,923  ???:0x00000000048e9130 [???]
#   572,508  /build/glibc-SzIz7B/glibc-2.31/libio/libioP.h:fflush
#   572,301  /build/glibc-SzIz7B/glibc-2.31/elf/dl-lookup.c:do_lookup_x [/usr/lib/x86_64-linux-gnu/ld-2.31.so]
#   542,660  /build/glibc-SzIz7B/glibc-2.31/libio/fileops.c:_IO_file_sync@@GLIBC_2.2.5 [/usr/lib/x86_64-linux-gnu/libc-2.31.so]
#   541,836  ???:0x0000000000126f00 [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
#   527,435  aleatoriedade.cpp:compara_filme(Filme, Filme) [/home/user/log-comp-davirvs/supercomputacao/projetos/maratona-filmes/aleatoriedade]
#   508,020  /usr/include/c++/9/bits/move.h:void std::__introsort_loop<__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)> >(__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)>)'2
#   451,935  ???:std::ostream::flush() [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
#   444,753  ???:0x00000000048e6880 [???]
#   404,742  /usr/include/c++/9/bits/stl_algo.h:void std::__introsort_loop<__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)> >(__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)>)'2 [/home/user/log-comp-davirvs/supercomputacao/projetos/maratona-filmes/aleatoriedade]
#   297,429  /usr/include/c++/9/bits/stl_tree.h:main
#   283,539  aleatoriedade.cpp:main [/home/user/log-comp-davirvs/supercomputacao/projetos/maratona-filmes/aleatoriedade]
#   275,569  /build/glibc-SzIz7B/glibc-2.31/elf/../sysdeps/x86_64/dl-machine.h:_dl_relocate_object
#   270,490  /usr/include/c++/9/bits/stl_tree.h:aleatoriedade(std::vector<Categoria, std::allocator<Categoria> >&, Maratona&, std::map<int, std::vector<Filme, std::allocator<Filme> >, std::less<int>, std::allocator<std::pair<int const, std::vector<Filme, std::allocator<Filme> > > > >)
#   197,806  /usr/include/c++/9/bitset:gera_horario(int, int)
#   197,476  /usr/include/c++/9/bits/stl_uninitialized.h:void std::vector<Filme, std::allocator<Filme> >::_M_realloc_insert<Filme const&>(__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, Filme const&)
#   182,190  ???:std::locale::id::_M_id() const [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
#   177,338  /usr/include/c++/9/bits/predefined_ops.h:void std::__introsort_loop<__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)> >(__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)>)
#   163,152  /build/glibc-SzIz7B/glibc-2.31/stdlib/random_r.c:srandom_r [/usr/lib/x86_64-linux-gnu/libc-2.31.so]
#   162,635  aleatoriedade.cpp:gera_horario(int, int) [/home/user/log-comp-davirvs/supercomputacao/projetos/maratona-filmes/aleatoriedade]
#   153,769  /usr/include/c++/9/bits/stl_vector.h:main
#   129,904  /usr/include/c++/9/bits/stl_algo.h:main
#   119,220  /build/glibc-SzIz7B/glibc-2.31/elf/dl-lookup.c:check_match [/usr/lib/x86_64-linux-gnu/ld-2.31.so]
#   106,348  /usr/include/c++/9/bits/move.h:void std::__introsort_loop<__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)> >(__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)>)
#    90,749  /build/glibc-SzIz7B/glibc-2.31/elf/do-rel.h:_dl_relocate_object
#    90,387  ???:__gnu_cxx::stdio_sync_filebuf<char, std::char_traits<char> >::sync() [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
#    90,258  /usr/include/c++/9/bits/stl_algo.h:void std::__introsort_loop<__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)> >(__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, long, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)>) [/home/user/log-comp-davirvs/supercomputacao/projetos/maratona-filmes/aleatoriedade]
#    85,980  /build/glibc-SzIz7B/glibc-2.31/string/../sysdeps/x86_64/strcmp.S:strcmp [/usr/lib/x86_64-linux-gnu/ld-2.31.so]
#    85,707  /usr/include/c++/9/bits/predefined_ops.h:main
#    71,545  /build/glibc-SzIz7B/glibc-2.31/elf/dl-addr.c:_dl_addr [/usr/lib/x86_64-linux-gnu/libc-2.31.so]
#    60,607  ???:0x00000000048e64f0 [???]
#    60,269  ???:0x00000000048e9080 [???]
#    60,264  /build/glibc-SzIz7B/glibc-2.31/libio/../sysdeps/unix/sysv/linux/x86/lowlevellock.h:fflush
#    60,215  ???:0x00000000048e7530 [???]
#    60,209  ???:0x00000000048e6f30 [???]
#    60,209  ???:0x00000000048e86a0 [???]
#    60,204  ???:0x000000000010a2b0 [???]
#    60,204  ???:std::num_get<char, std::istreambuf_iterator<char, std::char_traits<char> > >::do_get(std::istreambuf_iterator<char, std::char_traits<char> >, std::istreambuf_iterator<char, std::char_traits<char> >, std::ios_base&, std::_Ios_Iostate&, long&) const [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.28]
#    50,214  /usr/include/c++/9/bits/stl_uninitialized.h:std::_Rb_tree_node<std::pair<int const, std::vector<Filme, std::allocator<Filme> > > >* std::_Rb_tree<int, std::pair<int const, std::vector<Filme, std::allocator<Filme> > >, std::_Select1st<std::pair<int const, std::vector<Filme, std::allocator<Filme> > > >, std::less<int>, std::allocator<std::pair<int const, std::vector<Filme, std::allocator<Filme> > > > >::_M_copy<std::_Rb_tree<int, std::pair<int const, std::vector<Filme, std::allocator<Filme> > >, std::_Select1st<std::pair<int const, std::vector<Filme, std::allocator<Filme> > > >, std::less<int>, std::allocator<std::pair<int const, std::vector<Filme, std::allocator<Filme> > > > >::_Alloc_node>(std::_Rb_tree_node<std::pair<int const, std::vector<Filme, std::allocator<Filme> > > > const*, std::_Rb_tree_node_base*, std::_Rb_tree<int, std::pair<int const, std::vector<Filme, std::allocator<Filme> > >, std::_Select1st<std::pair<int const, std::vector<Filme, std::allocator<Filme> > > >, std::less<int>, std::allocator<std::pair<int const, std::vector<Filme, std::allocator<Filme> > > > >::_Alloc_node&)'2
#    46,897  /build/glibc-SzIz7B/glibc-2.31/malloc/malloc.c:_int_malloc [/usr/lib/x86_64-linux-gnu/libc-2.31.so]
#    36,755  /usr/include/c++/9/bits/stl_map.h:main
#    31,912  /usr/include/c++/9/bits/stl_map.h:aleatoriedade(std::vector<Categoria, std::allocator<Categoria> >&, Maratona&, std::map<int, std::vector<Filme, std::allocator<Filme> >, std::less<int>, std::allocator<std::pair<int const, std::vector<Filme, std::allocator<Filme> > > > >)
#    28,881  /usr/include/c++/9/new:void std::vector<Filme, std::allocator<Filme> >::_M_realloc_insert<Filme const&>(__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, Filme const&)
#    27,973  /build/glibc-SzIz7B/glibc-2.31/malloc/malloc.c:_int_free [/usr/lib/x86_64-linux-gnu/libc-2.31.so]
#    24,365  aleatoriedade.cpp:aleatoriedade(std::vector<Categoria, std::allocator<Categoria> >&, Maratona&, std::map<int, std::vector<Filme, std::allocator<Filme> >, std::less<int>, std::allocator<std::pair<int const, std::vector<Filme, std::allocator<Filme> > > > >) [/home/user/log-comp-davirvs/supercomputacao/projetos/maratona-filmes/aleatoriedade]
#    20,916  /usr/include/c++/9/bits/stl_algo.h:void std::__move_median_to_first<__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)> >(__gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__normal_iterator<Filme*, std::vector<Filme, std::allocator<Filme> > >, __gnu_cxx::__ops::_Iter_comp_iter<bool (*)(Filme, Filme)>) [/home/user/log-comp-davirvs/supercomputacao/projetos/maratona-filmes/aleatoriedade]
#
# --------------------------------------------------------------------------------
# -- User-annotated source: aleatoriedade.cpp
# --------------------------------------------------------------------------------
# Ir
#
# -- line 22 ----------------------------------------
#       .      int quantidade;
#       .  };
#       .
#       .  struct Maratona {
#       .      std::bitset<24> disponibilidade;
#       .      std::vector<Filme> filmes;
#       .  };
#       .
# 105,487  bool compara_filme(Filme a, Filme b) {
# 316,461      return a.fim < b.fim;
# 105,487  }
#       .
#  18,172  std::bitset<24> gera_horario(int inicio, int fim) {
#  18,042      std::bitset<24> horario;
#       .
#  18,172      if (inicio == fim) {
#      65          horario.set(inicio);
#     195          return horario;
#       .      }
#       .
#  62,885      for (int i = inicio; i < fim; i++) {
#  26,932          horario.set(i);
#       .      }
#       .
#       .      return horario;
#  18,172  }
#       .
#       .
#      14  void aleatoriedade(vector<Categoria> &categorias, Maratona &maratona, map<int, vector<Filme>> filmes_por_horario){
#       1      unsigned seed = std::chrono::system_clock::now().time_since_epoch().count();
#     992  => ???:0x000000000010a250 (1x)
#       1      std::default_random_engine generator (seed);
#       .      std::binomial_distribution<int> distribution (1, 0.75);
#       .      distribution(generator);
#       .
#       .      bitset<24> mochila_cheia(0xFFFFFF);
#       .
#     123      for (int i = 1; i <= 24; i++){
#      48          if (maratona.disponibilidade == mochila_cheia){
#       .              break;
#       .          }
#       .
#      72          if (filmes_por_horario[i].size() == 0){
#       .              continue;
#       .          }
#       .
#       .          Filme filme_escolhido;
#       .
#      96          srand(time(NULL));
# 163,608  => ???:0x000000000010a360 (24x)
#     192  => ???:0x000000000010a340 (24x)
#      92          if (distribution(generator)){
#   9,341              for (int j = 0; j < static_cast<int>(filmes_por_horario[i].size()); j++){
#   6,438                  if ((!(maratona.disponibilidade & filmes_por_horario[i][j].horario).any()) && (categorias[filmes_por_horario[i][j].categoria - 1].quantidade > 0)){
#     100                      filme_escolhido = filmes_por_horario[i][j];
#      20                      break;
#       .                  }
#       .
#   3,099                  filme_escolhido.id = -1;
#       .              }
#       .          } else {
#       .              vector<Filme> filmes_disponiveis_no_horario;
#       .
#   2,485              for (int j = 1; j < static_cast<int>(filmes_por_horario[i].size()); j++){
#   1,744                  if ((!(maratona.disponibilidade & filmes_por_horario[i][j].horario).any()) && (categorias[filmes_por_horario[i][j].categoria - 1].quantidade > 0)){
#       .                      filmes_disponiveis_no_horario.push_back(filmes_por_horario[i][j]);
#       .                  }
#       .              }
#       .
#       6              if (filmes_disponiveis_no_horario.size() == 0){
#       .                  continue;
#       .              }
#       .
#      22              filme_escolhido = filmes_disponiveis_no_horario[rand() % filmes_disponiveis_no_horario.size()];
#     124  => ???:0x000000000010a270 (2x)
#       .          }
#       .
#      48          if (filme_escolhido.id == -1){
#       .              continue;
#       .          }
#       .
#       .          maratona.disponibilidade |= filme_escolhido.horario;
#       6          maratona.filmes.push_back(filme_escolhido);
#      88          categorias[filme_escolhido.categoria - 1].quantidade--;
#       .      }
#       .
#       .      cout << maratona.filmes.size() << endl;
#       .
#      70      for (int i = 0; i < static_cast<int>(maratona.filmes.size()); i++){
#     440          cout << maratona.filmes[i].id << " " << maratona.filmes[i].inicio << " " << maratona.filmes[i].fim << " " << maratona.filmes[i].categoria << endl;
#  38,891  => ???:0x000000000010a420 (88x)
#       .      }
#       .
#       .      cout << endl;
#      11  }
#       .
#       .
#      11  int main() {
#       .      int n, m;
#       6      cin >> n >> m;
#   9,177  => ???:0x000000000010a2b0 (2x)
#       .      vector<Filme> filmes;
#       1      vector<Categoria> categorias(m);
#       .      Maratona maratona;
#       .
#     305      for (int i = 0; i < m; i++) {
#     301          cin >> categorias[i].quantidade;
# 121,283  => ???:0x000000000010a2b0 (100x)
#     300          categorias[i].id = i + 1;
#       .      }
#       .
#  20,005      for (int i = 0; i < n; i++) {
#       .          int inicio, fim, categoria;
# 100,001          cin >> inicio >> fim >> categoria;
# 34,747,066  => ???:0x000000000010a2b0 (30,000x)
#       .
#  50,000          if (inicio > fim) {
#   2,666              if (fim == 0){
#     838                  fim = 24;
#       .              } else if (inicio == -1 || fim == -1) {
#       .                  continue;
#       .              } else {
#       .                  continue;
#       .              }
#       .          }
#       .
#       .          Filme filme;
#   9,086          filme.id = i + 1;
#   9,086          filme.inicio = inicio;
#   9,086          filme.fim = fim;
#  18,172          filme.categoria = categoria;
#  18,172          filme.horario = gera_horario(inicio, fim);
# 360,441  => aleatoriedade.cpp:gera_horario(int, int) (9,086x)
#       .
#       .          filmes.push_back(filme);
#       .      }
#       .
#       .      sort(filmes.begin(), filmes.end(), compara_filme);
#       .
#       1      int size_of_filmes = filmes.size();
#       .
#       .      // for (int i = 0; i < size_of_f    ilmes; i++) {
#       .      //     cout << filmes[i].id << " " << filmes[i].inicio << " " << filmes[i].fim << endl;
#       .      // }
#       .
#       .      map<int, vector<Filme>> filmes_por_horario;
#       .
#  45,436      for (int i = 0; i < size_of_filmes; i++) {
#      50          filmes_por_horario[filmes[i].fim].push_back(filmes[i]);
#       .      }
#       .
#       4      aleatoriedade(categorias, maratona, filmes_por_horario);
# 605,510  => aleatoriedade.cpp:aleatoriedade(std::vector<Categoria, std::allocator<Categoria> >&, Maratona&, std::map<int, std::vector<Filme, std::allocator<Filme> >, std::less<int>, std::allocator<std::pair<int const, std::vector<Filme, std::allocator<Filme> > > > >) (1x)
#       .
#       .      return 0;
#       .
#      15  }
#
# --------------------------------------------------------------------------------
# Ir
# --------------------------------------------------------------------------------
# 997,977  events annotated
# ```

# %% [markdown]
# ### Paralelismo com OpenMP

# %%
# !valgrind --tool=callgrind --vgdb=no ./exaustiva < inputs/input-12.txt  > exaustiva_output_valgrind.txt
# Out:
# ==5326== Callgrind, a call-graph generating cache profiler
# ==5326== Copyright (C) 2002-2017, and GNU GPL'd, by Josef Weidendorfer et al.
# ==5326== Using Valgrind-3.18.1 and LibVEX; rerun with -h for copyright info
# ==5326== Command: ./exaustiva
# ==5326==
# ==5326== For interactive control, run 'callgrind_control -h'.
# ==5326==
# ==5326== Events    : Ir
# ==5326== Collected : 17961310
# ==5326==
# ==5326== I   refs:      17,961,310

# %%
# !callgrind_annotate callgrind.out.31063 exaustiva.cpp
# Out:
# --------------------------------------------------------------------------------
# Profile data file 'callgrind.out.31063' (creator: callgrind-3.18.1)
# --------------------------------------------------------------------------------
# I1 cache:
# D1 cache:
# LL cache:
# Timerange: Basic block 0 - 3454209
# Trigger: Program termination
# Profiled target:  ./exaustiva (PID 31063, part 1)
# Events recorded:  Ir
# Events shown:     Ir
# Event sort order: Ir
# Thresholds:       99
# Include dirs:
# User annotated:   exaustiva.cpp
# Auto-annotation:  on
#
# --------------------------------------------------------------------------------
# Ir
# --------------------------------------------------------------------------------
# 17,869,305 (100.0%)  PROGRAM TOTALS
#
# --------------------------------------------------------------------------------
# Ir                  file:function
# --------------------------------------------------------------------------------
# 1,668,839 ( 9.34%)  ???:0x00000000000208a0 [/usr/lib/x86_64-linux-gnu/libgomp.so.1.0.0]
# 1,318,962 ( 7.38%)  ???:busca_exaustiva(std::vector<Filme, std::allocator<Filme> >&, std::vector<Categoria, std::allocator<Categoria> >&, Maratona&) [clone ._omp_fn.0] [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   991,623 ( 5.55%)  ./elf/./elf/dl-lookup.c:_dl_lookup_symbol_x [/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2]
#   942,816 ( 5.28%)  ???:0x0000000000020640 [/usr/lib/x86_64-linux-gnu/libgomp.so.1.0.0]
#   743,424 ( 4.16%)  ???:std::bitset<64ul>::reference::reference(std::bitset<64ul>&, unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   592,688 ( 3.32%)  ./elf/./elf/dl-lookup.c:do_lookup_x [/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2]
#   540,968 ( 3.03%)  ???:std::_Base_bitset<1ul>::_S_whichbit(unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   540,672 ( 3.03%)  ???:std::bitset<64ul>::operator[](unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   473,606 ( 2.65%)  ???:std::_Base_bitset<1ul>::_S_maskbit(unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   430,260 ( 2.41%)  ???:std::vector<Filme, std::allocator<Filme> >::operator[](unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   428,032 ( 2.40%)  ???:std::bitset<64ul>::reference::operator bool() const [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   394,025 ( 2.21%)  ./malloc/./malloc/malloc.c:_int_free [/usr/lib/x86_64-linux-gnu/libc.so.6]
#   281,600 ( 1.58%)  ???:std::bitset<64ul>::reference::operator=(bool) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   270,632 ( 1.51%)  ???:std::_Base_bitset<1ul>::_M_getword(unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   266,165 ( 1.49%)  ./malloc/./malloc/malloc.c:malloc [/usr/lib/x86_64-linux-gnu/libc.so.6]
#   262,654 ( 1.47%)  ./elf/../sysdeps/x86_64/dl-machine.h:_dl_relocate_object
#   259,072 ( 1.45%)  ???:std::bitset<24ul> std::operator&<24ul>(std::bitset<24ul> const&, std::bitset<24ul> const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   236,544 ( 1.32%)  ???:std::bitset<64ul>::reference::~reference() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   202,752 ( 1.13%)  ???:std::_Deque_base<Filme, std::allocator<Filme> >::_M_initialize_map(unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   202,752 ( 1.13%)  ???:std::bitset<24ul>::bitset(unsigned long long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   168,960 ( 0.95%)  ???:std::_Base_bitset<1ul>::_M_do_and(std::_Base_bitset<1ul> const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   168,200 ( 0.94%)  ???:std::deque<Filme, std::allocator<Filme> >::push_back(Filme const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   157,696 ( 0.88%)  ???:std::bitset<24ul>::operator&=(std::bitset<24ul> const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   157,275 ( 0.88%)  ???:void __gnu_cxx::new_allocator<Filme>::construct<Filme, Filme const&>(Filme*, Filme const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   147,456 ( 0.83%)  ???:std::__deque_buf_size(unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   146,432 ( 0.82%)  ???:std::_Base_bitset<1ul>::_Base_bitset(unsigned long long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   146,432 ( 0.82%)  ???:std::_Base_bitset<1ul>::_M_is_equal(std::_Base_bitset<1ul> const&) const [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   146,432 ( 0.82%)  ???:std::bitset<24ul>::operator==(std::bitset<24ul> const&) const [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   135,410 ( 0.76%)  ./malloc/./malloc/malloc.c:free [/usr/lib/x86_64-linux-gnu/libc.so.6]
#   120,927 ( 0.68%)  ./elf/./elf/dl-lookup.c:check_match [/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2]
#   118,784 ( 0.66%)  ???:std::_Deque_iterator<Filme, Filme&, Filme*>::_M_set_node(Filme**) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   110,675 ( 0.62%)  ???:void std::allocator_traits<std::allocator<Filme> >::construct<Filme, Filme const&>(std::allocator<Filme>&, Filme*, Filme const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#   109,926 ( 0.62%)  ./elf/./elf/do-rel.h:_dl_relocate_object
#   106,496 ( 0.60%)  ???:__gnu_cxx::__enable_if<std::__is_scalar<int>::__value, void>::__type std::__fill_a1<int*, int>(int*, int*, int const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    98,640 ( 0.55%)  ???:std::_Deque_iterator<Filme, Filme&, Filme*>::_Deque_iterator(std::_Deque_iterator<Filme, Filme&, Filme*> const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    90,112 ( 0.50%)  ???:std::_Sanitize_val<24ul, true>::_S_do_sanitize_val(unsigned long long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    87,210 ( 0.49%)  ???:std::_Base_bitset<1ul>::_M_do_or(std::_Base_bitset<1ul> const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    81,613 ( 0.46%)  ???:Filme const& std::forward<Filme const&>(std::remove_reference<Filme const&>::type&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    81,439 ( 0.46%)  ./string/../sysdeps/x86_64/strcmp.S:strcmp [/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2]
#    81,396 ( 0.46%)  ???:std::bitset<24ul>::operator|=(std::bitset<24ul> const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    81,200 ( 0.45%)  ???:std::stack<Filme, std::deque<Filme, std::allocator<Filme> > >::push(Filme const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    79,872 ( 0.45%)  ???:std::deque<Filme, std::allocator<Filme> >::~deque() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    73,848 ( 0.41%)  ???:operator new(unsigned long) [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30]
#    69,632 ( 0.39%)  ???:std::_Deque_base<Filme, std::allocator<Filme> >::_M_get_map_allocator() const [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    69,600 ( 0.39%)  ???:std::vector<int, std::allocator<int> >::operator[](unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    67,584 ( 0.38%)  ???:std::allocator<int>::~allocator() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    65,536 ( 0.37%)  ???:std::_Deque_base<Filme, std::allocator<Filme> >::_M_allocate_map(unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    65,536 ( 0.37%)  ???:std::_Deque_base<Filme, std::allocator<Filme> >::~_Deque_base() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    65,536 ( 0.37%)  ???:std::vector<int, std::allocator<int> >::_S_check_init_len(unsigned long, std::allocator<int> const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    65,177 ( 0.36%)  ./malloc/./malloc/arena.c:free
#    63,488 ( 0.36%)  ???:std::vector<int, std::allocator<int> >::vector(unsigned long, int const&, std::allocator<int> const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    61,440 ( 0.34%)  ???:std::_Deque_iterator<Filme, Filme&, Filme*>::_Deque_iterator() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    59,392 ( 0.33%)  ???:std::_Deque_base<Filme, std::allocator<Filme> >::_M_deallocate_map(Filme**, unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    57,400 ( 0.32%)  ???:std::_Vector_base<Filme, std::allocator<Filme> >::~_Vector_base() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    57,344 ( 0.32%)  ???:std::allocator<int>::allocator(std::allocator<int> const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    55,539 ( 0.31%)  ???:__gnu_cxx::new_allocator<Filme>::allocate(unsigned long, void const*) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    55,296 ( 0.31%)  ???:std::_Deque_base<Filme, std::allocator<Filme> >::_M_create_nodes(Filme**, Filme**) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    55,296 ( 0.31%)  ???:std::_Deque_base<Filme, std::allocator<Filme> >::_M_destroy_nodes(Filme**, Filme**) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    55,296 ( 0.31%)  ???:std::_Vector_base<int, std::allocator<int> >::_M_create_storage(unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    51,200 ( 0.29%)  ???:std::_Vector_base<int, std::allocator<int> >::~_Vector_base() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    51,200 ( 0.29%)  ???:std::vector<int, std::allocator<int> >::_S_max_size(std::allocator<int> const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    49,152 ( 0.28%)  ???:__gnu_cxx::new_allocator<Filme*>::allocate(unsigned long, void const*) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    49,152 ( 0.28%)  ???:__gnu_cxx::new_allocator<int>::allocate(unsigned long, void const*) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    49,152 ( 0.28%)  ???:int* std::__fill_n_a<int*, unsigned long, int>(int*, unsigned long, int const&, std::random_access_iterator_tag) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    49,152 ( 0.28%)  ???:std::allocator<Filme*>::allocator<Filme>(std::allocator<Filme> const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    46,784 ( 0.26%)  ???:operator new(unsigned long, void*) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    45,100 ( 0.25%)  ???:std::vector<Filme, std::allocator<Filme> >::~vector() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    45,078 ( 0.25%)  ???:std::allocator<Filme>::allocator() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    45,078 ( 0.25%)  ???:std::allocator<Filme>::~allocator() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    45,056 ( 0.25%)  ???:std::_Vector_base<int, std::allocator<int> >::_Vector_base(unsigned long, std::allocator<int> const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    45,056 ( 0.25%)  ???:std::allocator<Filme*>::~allocator() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    45,056 ( 0.25%)  ???:std::stack<Filme, std::deque<Filme, std::allocator<Filme> > >::stack<std::deque<Filme, std::allocator<Filme> >, void>() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    45,056 ( 0.25%)  ???:std::vector<int, std::allocator<int> >::_M_fill_initialize(unsigned long, int const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    45,056 ( 0.25%)  ???:std::vector<int, std::allocator<int> >::~vector() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    43,008 ( 0.24%)  ???:__gnu_cxx::new_allocator<int>::~new_allocator() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    43,008 ( 0.24%)  ???:int* std::fill_n<int*, unsigned long, int>(int*, unsigned long, int const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    40,960 ( 0.23%)  ???:std::_Deque_base<Filme, std::allocator<Filme> >::_Deque_impl_data::_Deque_impl_data() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    39,083 ( 0.22%)  ???:__gnu_cxx::new_allocator<Filme>::deallocate(Filme*, unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    36,864 ( 0.21%)  ???:std::_Vector_base<int, std::allocator<int> >::_M_deallocate(int*, unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    36,864 ( 0.21%)  ???:std::bitset<64ul>::bitset(unsigned long long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    34,816 ( 0.19%)  ???:std::_Deque_base<Filme, std::allocator<Filme> >::_Deque_base() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    34,816 ( 0.19%)  ???:std::_Deque_base<Filme, std::allocator<Filme> >::_M_deallocate_node(Filme*) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    34,816 ( 0.19%)  ???:std::_Vector_base<int, std::allocator<int> >::_Vector_impl::_Vector_impl(std::allocator<int> const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    34,816 ( 0.19%)  ???:std::deque<Filme, std::allocator<Filme> >::_M_destroy_data(std::_Deque_iterator<Filme, Filme&, Filme*>, std::_Deque_iterator<Filme, Filme&, Filme*>, std::allocator<Filme> const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    32,912 ( 0.18%)  ???:std::allocator_traits<std::allocator<Filme> >::deallocate(std::allocator<Filme>&, Filme*, unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    32,768 ( 0.18%)  ???:__gnu_cxx::new_allocator<int>::new_allocator(__gnu_cxx::new_allocator<int> const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    32,768 ( 0.18%)  ???:int* std::__uninitialized_fill_n_a<int*, unsigned long, int, int>(int*, unsigned long, int const&, std::allocator<int>&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    32,768 ( 0.18%)  ???:int* std::uninitialized_fill_n<int*, unsigned long, int>(int*, unsigned long, int const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    32,768 ( 0.18%)  ???:std::_Vector_base<int, std::allocator<int> >::_M_allocate(unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    32,768 ( 0.18%)  ???:std::allocator_traits<std::allocator<Filme*> >::deallocate(std::allocator<Filme*>&, Filme**, unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    32,768 ( 0.18%)  ???:std::allocator_traits<std::allocator<int> >::deallocate(std::allocator<int>&, int*, unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    32,768 ( 0.18%)  ???:void std::__fill_a<int*, int>(int*, int*, int const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    30,930 ( 0.17%)  ???:std::deque<Filme, std::allocator<Filme> >::end() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    30,795 ( 0.17%)  ???:void std::_Destroy<Filme*, Filme>(Filme*, Filme*, std::allocator<Filme>&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    30,735 ( 0.17%)  ???:Maratona::Maratona() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    30,720 ( 0.17%)  ???:__gnu_cxx::new_allocator<Filme*>::deallocate(Filme**, unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    30,720 ( 0.17%)  ???:__gnu_cxx::new_allocator<int>::deallocate(int*, unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    30,720 ( 0.17%)  ???:int* std::__uninitialized_fill_n<true>::__uninit_fill_n<int*, unsigned long, int>(int*, unsigned long, int const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    30,720 ( 0.17%)  ???:std::deque<Filme, std::allocator<Filme> >::begin() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    30,720 ( 0.17%)  ???:void std::_Destroy<int*, int>(int*, int*, std::allocator<int>&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,938 ( 0.16%)  ???:unsigned long const& std::min<unsigned long>(unsigned long const&, unsigned long const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,800 ( 0.16%)  ???:unsigned long const& std::max<unsigned long>(unsigned long const&, unsigned long const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,798 ( 0.16%)  ???:std::allocator_traits<std::allocator<Filme> >::allocate(std::allocator<Filme>&, unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,742 ( 0.16%)  ???:void std::_Destroy<Filme*>(Filme*, Filme*) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,700 ( 0.16%)  ???:std::_Vector_base<Filme, std::allocator<Filme> >::_Vector_impl::_Vector_impl() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,686 ( 0.16%)  ???:__gnu_cxx::new_allocator<Filme>::new_allocator() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,686 ( 0.16%)  ???:__gnu_cxx::new_allocator<Filme>::~new_allocator() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,672 ( 0.16%)  ???:__gnu_cxx::new_allocator<Filme*>::new_allocator() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,672 ( 0.16%)  ???:__gnu_cxx::new_allocator<Filme*>::~new_allocator() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,672 ( 0.16%)  ???:__gnu_cxx::new_allocator<int>::_M_max_size() const [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,672 ( 0.16%)  ???:std::_Deque_base<Filme, std::allocator<Filme> >::_Deque_impl::_Deque_impl() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,672 ( 0.16%)  ???:std::_Deque_base<Filme, std::allocator<Filme> >::_M_allocate_node() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,672 ( 0.16%)  ???:std::_Deque_base<Filme, std::allocator<Filme> >::_M_get_Tp_allocator() const [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,672 ( 0.16%)  ???:std::_Deque_iterator<Filme, Filme&, Filme*>::_S_buffer_size() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,672 ( 0.16%)  ???:std::_Vector_base<int, std::allocator<int> >::_M_get_Tp_allocator() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,672 ( 0.16%)  ???:std::allocator_traits<std::allocator<Filme*> >::allocate(std::allocator<Filme*>&, unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,672 ( 0.16%)  ???:std::allocator_traits<std::allocator<int> >::allocate(std::allocator<int>&, unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    28,672 ( 0.16%)  ???:void std::_Destroy<int*>(int*, int*) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    26,650 ( 0.15%)  ???:std::_Vector_base<Filme, std::allocator<Filme> >::_Vector_impl_data::_Vector_impl_data() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    26,624 ( 0.15%)  ???:std::_Vector_base<int, std::allocator<int> >::_Vector_impl_data::_Vector_impl_data() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    26,624 ( 0.15%)  ???:std::vector<Categoria, std::allocator<Categoria> >::size() const [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    24,762 ( 0.14%)  ???:std::_Vector_base<Filme, std::allocator<Filme> >::_M_deallocate(Filme*, unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    24,588 ( 0.14%)  ???:Maratona::~Maratona() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    22,660 ( 0.13%)  ???:std::bitset<24ul>::bitset() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    22,550 ( 0.13%)  ???:std::_Vector_base<Filme, std::allocator<Filme> >::_Vector_base() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    22,550 ( 0.13%)  ???:std::_Vector_base<Filme, std::allocator<Filme> >::_Vector_impl::~_Vector_impl() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    22,550 ( 0.13%)  ???:std::vector<Filme, std::allocator<Filme> >::vector() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    22,528 ( 0.13%)  ???:std::_Deque_base<Filme, std::allocator<Filme> >::_Deque_impl::~_Deque_impl() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    22,528 ( 0.13%)  ???:std::_Vector_base<int, std::allocator<int> >::_Vector_impl::~_Vector_impl() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    22,528 ( 0.13%)  ???:std::allocator<int>::allocator() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    22,528 ( 0.13%)  ???:std::deque<Filme, std::allocator<Filme> >::deque() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    22,528 ( 0.13%)  ???:std::stack<Filme, std::deque<Filme, std::allocator<Filme> > >::~stack() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    20,480 ( 0.11%)  ???:__gnu_cxx::new_allocator<int>::max_size() const [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    20,480 ( 0.11%)  ???:std::allocator_traits<std::allocator<int> >::max_size(std::allocator<int> const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    20,097 ( 0.11%)  ./elf/../sysdeps/generic/dl-protected.h:do_lookup_x
#    18,540 ( 0.10%)  ???:std::_Base_bitset<1ul>::_Base_bitset() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    16,424 ( 0.09%)  ???:void std::_Destroy_aux<true>::__destroy<Filme*>(Filme*, Filme*) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    16,384 ( 0.09%)  ???:void std::_Destroy_aux<true>::__destroy<int*>(int*, int*) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    15,778 ( 0.09%)  ./malloc/./malloc/malloc.c:_int_malloc [/usr/lib/x86_64-linux-gnu/libc.so.6]
#    15,540 ( 0.09%)  ./elf/./elf/dl-version.c:_dl_check_map_versions [/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2]
#    14,611 ( 0.08%)  ./malloc/./malloc/malloc.c:arena_get2.part.0
#    14,589 ( 0.08%)  ./elf/./elf/dl-tunables.c:__GI___tunables_init [/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2]
#    14,525 ( 0.08%)  ???:__gnu_cxx::new_allocator<Filme>::_M_max_size() const [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    14,497 ( 0.08%)  ???:std::_Vector_base<Filme, std::allocator<Filme> >::_M_get_Tp_allocator() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    14,434 ( 0.08%)  ???:std::_Deque_base<Filme, std::allocator<Filme> >::_M_get_Tp_allocator() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    14,343 ( 0.08%)  ???:std::__size_to_integer(unsigned long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    14,336 ( 0.08%)  ???:__gnu_cxx::new_allocator<Filme*>::_M_max_size() const [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    14,336 ( 0.08%)  ???:__gnu_cxx::new_allocator<int>::new_allocator() [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    14,336 ( 0.08%)  ???:std::_Sanitize_val<64ul, false>::_S_do_sanitize_val(unsigned long long) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    12,315 ( 0.07%)  ???:0x00000000048e70e0 [???]
#    12,313 ( 0.07%)  ???:0x00000000048e72f0 [???]
#    12,313 ( 0.07%)  ???:0x00000000048e7b50 [???]
#    12,308 ( 0.07%)  ???:0x0000000000109250 [???]
#    12,308 ( 0.07%)  ???:0x0000000000109260 [???]
#    12,308 ( 0.07%)  ???:operator delete(void*) [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30]
#    12,308 ( 0.07%)  ???:operator delete(void*, unsigned long) [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30]
#    12,288 ( 0.07%)  ???:GOMP_critical_end [/usr/lib/x86_64-linux-gnu/libgomp.so.1.0.0]
#    12,288 ( 0.07%)  ???:GOMP_critical_start [/usr/lib/x86_64-linux-gnu/libgomp.so.1.0.0]
#    12,288 ( 0.07%)  ???:std::iterator_traits<int*>::iterator_category std::__iterator_category<int*>(int* const&) [/mnt/c/Users/vieir/OneDrive/Documentos/Insper/7-semestre/super-comp/Projeto-SuperComp/exaustiva]
#    12,128 ( 0.07%)  ???:std::locale::_Impl::_M_install_facet(std::locale::id const*, std::locale::facet const*) [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30]
#    11,095 ( 0.06%)  ./elf/../sysdeps/generic/ldsodefs.h:do_lookup_x
#    10,372 ( 0.06%)  ???:std::istreambuf_iterator<char, std::char_traits<char> > std::num_get<char, std::istreambuf_iterator<char, std::char_traits<char> > >::_M_extract_int<long>(std::istreambuf_iterator<char, std::char_traits<char> >, std::istreambuf_iterator<char, std::char_traits<char> >, std::ios_base&, std::_Ios_Iostate&, long&) const [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30]
#    10,240 ( 0.06%)  ./wcsmbs/./wcsmbs/btowc.c:btowc [/usr/lib/x86_64-linux-gnu/libc.so.6]
#    10,221 ( 0.06%)  ./elf/../sysdeps/generic/ldsodefs.h:_dl_relocate_object
#    10,160 ( 0.06%)  ./elf/./elf/dl-runtime.c:_dl_fixup [/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2]
#     7,730 ( 0.04%)  ./libio/./libio/getc.c:getc [/usr/lib/x86_64-linux-gnu/libc.so.6]
#     6,356 ( 0.04%)  ./stdlib/./stdlib/getenv.c:getenv [/usr/lib/x86_64-linux-gnu/libc.so.6]
#     5,700 ( 0.03%)  ./libio/./libio/genops.c:_IO_sputbackc [/usr/lib/x86_64-linux-gnu/libc.so.6]
#     5,400 ( 0.03%)  ./libio/./libio/ioungetc.c:ungetc [/usr/lib/x86_64-linux-gnu/libc.so.6]
#     4,586 ( 0.03%)  ./elf/./elf/dl-load.c:_dl_map_object_from_fd [/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2]
#     4,387 ( 0.02%)  ./elf/../sysdeps/x86_64/dl-trampoline.h:_dl_runtime_resolve_xsave [/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2]
#     4,339 ( 0.02%)  ./elf/./elf/dl-misc.c:_dl_name_match_p [/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2]
#     4,301 ( 0.02%)  ./elf/./elf/dl-reloc.c:_dl_relocate_object [/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2]
#     4,096 ( 0.02%)  ???:0x0000000000109200 [???]
#     4,096 ( 0.02%)  ???:0x0000000000109230 [???]
#     3,838 ( 0.02%)  ./elf/../elf/dl-tls.c:_dl_allocate_tls [/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2]
#
# --------------------------------------------------------------------------------
# -- User-annotated source: exaustiva.cpp
# --------------------------------------------------------------------------------
#   No information has been collected for exaustiva.cpp
#
# --------------------------------------------------------------------------------
# The following files chosen for auto-annotation could not be found:
# --------------------------------------------------------------------------------
#   ./elf/../elf/dl-tls.c
#   ./elf/../sysdeps/generic/dl-protected.h
#   ./elf/../sysdeps/generic/ldsodefs.h
#   ./elf/../sysdeps/x86_64/dl-machine.h
#   ./elf/../sysdeps/x86_64/dl-trampoline.h
#   ./elf/./elf/dl-load.c
#   ./elf/./elf/dl-lookup.c
#   ./elf/./elf/dl-misc.c
#   ./elf/./elf/dl-reloc.c
#   ./elf/./elf/dl-runtime.c
#   ./elf/./elf/dl-tunables.c
#   ./elf/./elf/dl-version.c
#   ./elf/./elf/do-rel.h
#   ./libio/./libio/genops.c
#   ./libio/./libio/getc.c
#   ./libio/./libio/ioungetc.c
#   ./malloc/./malloc/arena.c
#   ./malloc/./malloc/malloc.c
#   ./stdlib/./stdlib/getenv.c
#   ./string/../sysdeps/x86_64/strcmp.S
#   ./wcsmbs/./wcsmbs/btowc.c

# %% [markdown]
# ### Paralelismo com GPU

# %%
# !valgrind --tool=callgrind --vgdb=no ./exaustiva_thrust < inputs/input-12.txt  > exaustiva_thrust_output_valgrind.txt
# Out:
# ==5354== Callgrind, a call-graph generating cache profiler
# ==5354== Copyright (C) 2002-2017, and GNU GPL'd, by Josef Weidendorfer et al.
# ==5354== Using Valgrind-3.18.1 and LibVEX; rerun with -h for copyright info
# ==5354== Command: ./exaustiva_thrust
# ==5354==
# ==5354== For interactive control, run 'callgrind_control -h'.
# ==5354== Warning: noted but unhandled ioctl 0x30000002 with no size/direction hints.
# ==5354==    This could cause spurious value errors to appear.
# ==5354==    See README_MISSING_SYSCALL_OR_IOCTL for guidance on writing a proper wrapper.
# ==5354== brk segment overflow in thread #1: can't grow to 0x490e000
# ==5354== (see section Limitations in user manual)
# ==5354== NOTE: further instances of this message will not be shown
# ==5354==
# ==5354== Events    : Ir
# ==5354== Collected : 461949650
# ==5354==
# ==5354== I   refs:      461,949,650

# %%
# !callgrind_annotate callgrind.out.5354 exaustiva_thrust.cu
# Out:
# --------------------------------------------------------------------------------
# Profile data file 'callgrind.out.5354' (creator: callgrind-3.18.1)
# --------------------------------------------------------------------------------
# I1 cache:
# D1 cache:
# LL cache:
# Timerange: Basic block 0 - 103972040
# Trigger: Program termination
# Profiled target:  ./exaustiva_thrust (PID 5354, part 1)
# Events recorded:  Ir
# Events shown:     Ir
# Event sort order: Ir
# Thresholds:       99
# Include dirs:
# User annotated:   exaustiva_thrust.cu
# Auto-annotation:  on
#
# --------------------------------------------------------------------------------
# Ir
# --------------------------------------------------------------------------------
# 461,949,650 (100.0%)  PROGRAM TOTALS
#
# --------------------------------------------------------------------------------
# Ir                   file:function
# --------------------------------------------------------------------------------
# 48,829,591 (10.57%)  ???:0x00000000000d8ff5 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
# 31,593,491 ( 6.84%)  ???:0x0000000000decd30 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
# 23,118,958 ( 5.00%)  ???:0x0000000000e450f0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
# 20,783,620 ( 4.50%)  ???:0x0000000000dec270 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
# 19,017,155 ( 4.12%)  ???:0x0000000000140ac0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
# 13,325,292 ( 2.88%)  ???:0x0000000000ddfc60 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
# 12,428,111 ( 2.69%)  ???:0x0000000000250db0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  9,633,011 ( 2.09%)  ???:0x0000000000deb480 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  6,724,995 ( 1.46%)  ./string/../sysdeps/x86_64/multiarch/memset-vec-unaligned-erms.S:__memset_avx2_unaligned_erms [/usr/lib/x86_64-linux-gnu/libc.so.6]
#  5,743,056 ( 1.24%)  ???:0x000000000024ac00 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  5,555,521 ( 1.20%)  ???:0x00000000009d4670 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  4,748,226 ( 1.03%)  ???:0x00000000002d1720 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#  4,200,718 ( 0.91%)  ???:0x000000000024fc30 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  4,083,952 ( 0.88%)  ./nptl/./nptl/pthread_mutex_lock.c:pthread_mutex_lock@@GLIBC_2.2.5 [/usr/lib/x86_64-linux-gnu/libc.so.6]
#  3,705,912 ( 0.80%)  ???:0x0000000000e3d080 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  3,417,324 ( 0.74%)  ./nptl/./nptl/pthread_mutex_unlock.c:pthread_mutex_unlock@@GLIBC_2.2.5 [/usr/lib/x86_64-linux-gnu/libc.so.6]
#  3,170,544 ( 0.69%)  ???:0x000000000024b5c0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  3,115,860 ( 0.67%)  ???:0x0000000000338870 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  3,089,829 ( 0.67%)  ???:0x0000000000334d10 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  2,863,231 ( 0.62%)  ???:0x000000000032e460 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  2,629,167 ( 0.57%)  ???:0x000000000029d1b0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  2,593,814 ( 0.56%)  ???:0x0000000000e41e90 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  2,525,918 ( 0.55%)  ./string/../sysdeps/x86_64/multiarch/strcmp-avx2.S:__strcmp_avx2 [/usr/lib/x86_64-linux-gnu/libc.so.6]
#  2,475,325 ( 0.54%)  ???:0x000000000013fcc0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  2,441,757 ( 0.53%)  ???:0x00000000003054c0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  2,328,537 ( 0.50%)  ./malloc/./malloc/malloc.c:_int_malloc [/usr/lib/x86_64-linux-gnu/libc.so.6]
#  2,319,929 ( 0.50%)  ???:0x000000000016cf20 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#  2,237,796 ( 0.48%)  ???:0x00000000002c9df0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#  2,055,568 ( 0.44%)  ./stdio-common/./stdio-common/vfscanf-internal.c:__vfscanf_internal [/usr/lib/x86_64-linux-gnu/libc.so.6]
#  1,984,233 ( 0.43%)  ./nptl/./nptl/pthread_getspecific.c:pthread_getspecific@@GLIBC_2.34 [/usr/lib/x86_64-linux-gnu/libc.so.6]
#  1,935,607 ( 0.42%)  ???:0x000000000033cef0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,862,265 ( 0.40%)  ???:0x000000000032f700 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,816,238 ( 0.39%)  ???:0x000000000040a810 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,808,020 ( 0.39%)  ???:0x00000000003347e0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,775,403 ( 0.38%)  ???:0x0000000000368b30 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,759,609 ( 0.38%)  ???:0x0000000000e3d5c0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,701,572 ( 0.37%)  ???:0x00000000002a3780 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,632,791 ( 0.35%)  ???:0x0000000000335560 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,615,337 ( 0.35%)  ???:0x000000000030a910 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,606,661 ( 0.35%)  ???:0x00000000002fed40 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,586,242 ( 0.34%)  ???:0x0000000000aa1020 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,501,447 ( 0.33%)  ???:0x0000000000e44540 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,486,803 ( 0.32%)  ???:0x0000000000e47590 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,451,403 ( 0.31%)  ???:0x0000000000309540 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#  1,427,257 ( 0.31%)  ???:0x0000000000ab08f0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,426,404 ( 0.31%)  ???:0x000000000044af20 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#  1,422,015 ( 0.31%)  ???:0x000000000037e7d0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,415,887 ( 0.31%)  ./elf/./elf/dl-lookup.c:do_lookup_x [/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2]
#  1,402,073 ( 0.30%)  ./string/../sysdeps/x86_64/multiarch/memmove-vec-unaligned-erms.S:memcpy@GLIBC_2.2.5 [/usr/lib/x86_64-linux-gnu/libc.so.6]
#  1,400,648 ( 0.30%)  ???:0x0000000000335f90 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,399,165 ( 0.30%)  ???:0x0000000000e3bd10 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,356,027 ( 0.29%)  ???:0x0000000000241830 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,327,939 ( 0.29%)  ???:0x000000000032ee90 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,323,466 ( 0.29%)  ???:0x000000000024d360 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,321,940 ( 0.29%)  ???:0x000000000040b250 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,312,037 ( 0.28%)  ./elf/./elf/dl-lookup.c:_dl_lookup_symbol_x [/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2]
#  1,304,696 ( 0.28%)  ???:0x000000000040ae20 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,249,353 ( 0.27%)  ???:0x00000000002b8b00 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,132,666 ( 0.25%)  ???:0x0000000000155980 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#  1,126,852 ( 0.24%)  ???:0x000000000040abb0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,115,469 ( 0.24%)  ???:0x0000000000403990 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,111,168 ( 0.24%)  ???:0x0000000000281c40 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,105,452 ( 0.24%)  ???:0x000000000040bbd0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,094,627 ( 0.24%)  ???:0x00000000009f3b80 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,028,194 ( 0.22%)  ???:0x000000000040baf0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,026,781 ( 0.22%)  ???:0x0000000000aae1f0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,010,488 ( 0.22%)  ???:0x0000000000291d90 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#  1,000,187 ( 0.22%)  ???:0x00000000001941a0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    950,635 ( 0.21%)  ???:0x0000000000b59920 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    938,918 ( 0.20%)  ???:0x00000000002b46e0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    922,535 ( 0.20%)  ./elf/../sysdeps/x86_64/dl-machine.h:_dl_relocate_object
#    911,636 ( 0.20%)  ???:0x000000000023f080 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    899,139 ( 0.19%)  ???:0x00000000001939a0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    898,539 ( 0.19%)  ???:0x000000000033df20 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    891,820 ( 0.19%)  ???:0x0000000000291da0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    885,138 ( 0.19%)  ???:0x000000000024e160 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    870,471 ( 0.19%)  ???:0x000000000023e590 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    856,324 ( 0.19%)  ???:0x000000000032ebb0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    847,759 ( 0.18%)  ???:0x0000000000265590 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    847,515 ( 0.18%)  ???:0x000000000044b0a0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    840,083 ( 0.18%)  ???:0x00000000001b78d0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    830,668 ( 0.18%)  ???:0x00000000001feb20 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    795,109 ( 0.17%)  ???:0x0000000000e3ca40 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    793,369 ( 0.17%)  ???:0x0000000000a85cd0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    788,513 ( 0.17%)  ???:0x00000000001fe5c0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    783,614 ( 0.17%)  ???:0x0000000000e41240'2 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    783,292 ( 0.17%)  ???:0x00000000002d2730 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    779,353 ( 0.17%)  ???:0x000000000024c790 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    778,020 ( 0.17%)  ???:0x0000000000b590a0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    765,966 ( 0.17%)  ???:0x0000000000e41960'2 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    752,698 ( 0.16%)  ???:0x00000000003af660 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    745,291 ( 0.16%)  ???:0x000000000037d390 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    721,724 ( 0.16%)  ???:0x0000000000369520 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    716,266 ( 0.16%)  ???:0x0000000000c66000 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    714,616 ( 0.15%)  ./malloc/./malloc/malloc.c:calloc [/usr/lib/x86_64-linux-gnu/libc.so.6]
#    710,798 ( 0.15%)  ???:0x00000000003a8b30 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    710,378 ( 0.15%)  ./stdio-common/./stdio-common/vfprintf-internal.c:__vfprintf_internal [/usr/lib/x86_64-linux-gnu/libc.so.6]
#    705,590 ( 0.15%)  ???:0x0000000000aa5c60 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    691,683 ( 0.15%)  ???:0x0000000000366ac0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    669,349 ( 0.14%)  ???:0x0000000000deb150 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    658,029 ( 0.14%)  ???:0x00000000003352d0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    650,786 ( 0.14%)  ???:0x000000000024a6a0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    649,632 ( 0.14%)  ???:0x0000000000ab53e0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    645,660 ( 0.14%)  ???:0x000000000040bbe0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    644,294 ( 0.14%)  ???:0x0000000000b908d0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    630,823 ( 0.14%)  ???:0x000000000029bb70 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    629,578 ( 0.14%)  ???:0x0000000000335e20 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    596,075 ( 0.13%)  ???:0x000000000013d050 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    593,801 ( 0.13%)  ???:0x00000000009d4940 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    590,596 ( 0.13%)  ???:0x00000000002fecc0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    590,399 ( 0.13%)  ???:0x0000000000c64a20 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    590,218 ( 0.13%)  ???:0x00000000001b5a50 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    590,109 ( 0.13%)  ???:0x0000000000c62e80 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    575,632 ( 0.12%)  ???:0x0000000000a89520 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    574,034 ( 0.12%)  ???:0x00000000002c9230 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    567,140 ( 0.12%)  ???:0x0000000000dce880 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    563,335 ( 0.12%)  ???:0x0000000000b946d0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    560,053 ( 0.12%)  ./malloc/./malloc/malloc.c:_int_free [/usr/lib/x86_64-linux-gnu/libc.so.6]
#    558,979 ( 0.12%)  ???:0x000000000024de20 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    552,156 ( 0.12%)  ???:0x00000000001fe620 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    539,308 ( 0.12%)  ???:0x00000000003aa7c0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    532,866 ( 0.12%)  ???:0x0000000000250cd0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    528,005 ( 0.11%)  ???:0x0000000000a9ff60 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    523,560 ( 0.11%)  ???:0x0000000000af9200 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    520,757 ( 0.11%)  ???:0x00000000003348b0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    519,419 ( 0.11%)  ???:0x0000000000196550 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    511,601 ( 0.11%)  ./string/../sysdeps/x86_64/multiarch/strcpy-avx2.S:__strcpy_avx2 [/usr/lib/x86_64-linux-gnu/libc.so.6]
#    511,425 ( 0.11%)  ???:0x0000000000bd8c60 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    505,793 ( 0.11%)  ./elf/./elf/do-rel.h:_dl_relocate_object
#    501,318 ( 0.11%)  ???:0x000000000016e100 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    496,405 ( 0.11%)  ???:0x0000000000aa9590 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    490,792 ( 0.11%)  ???:0x00000000003340b0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    483,897 ( 0.10%)  ???:0x000000000040c790 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    478,971 ( 0.10%)  ???:0x0000000000a97720 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    477,838 ( 0.10%)  ./stdlib/../stdlib/strtol_l.c:____strtol_l_internal [/usr/lib/x86_64-linux-gnu/libc.so.6]
#    476,536 ( 0.10%)  ???:0x000000000032feb0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    475,962 ( 0.10%)  ???:0x0000000000e3b3a0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    467,516 ( 0.10%)  ???:0x0000000000c19000 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    464,420 ( 0.10%)  ???:0x0000000000aa66d0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    457,782 ( 0.10%)  ???:0x0000000000a9f860 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    452,859 ( 0.10%)  ???:0x00000000002fb760 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    444,741 ( 0.10%)  ???:0x00000000009d4180 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    436,729 ( 0.09%)  ???:0x00000000002d0370 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    435,484 ( 0.09%)  ???:0x0000000000368d30 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    434,570 ( 0.09%)  ???:0x00000000003ab3f0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    432,869 ( 0.09%)  ???:0x000000000024a660 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    429,611 ( 0.09%)  ./string/../sysdeps/x86_64/multiarch/strlen-avx2.S:__strlen_avx2 [/usr/lib/x86_64-linux-gnu/libc.so.6]
#    426,755 ( 0.09%)  ???:0x0000000000427750 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    425,296 ( 0.09%)  ???:0x00000000002826e0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    423,746 ( 0.09%)  ???:0x00000000002bbec0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    422,480 ( 0.09%)  ./malloc/./malloc/malloc.c:malloc [/usr/lib/x86_64-linux-gnu/libc.so.6]
#    419,742 ( 0.09%)  ???:0x0000000000aba700 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    418,634 ( 0.09%)  ???:0x0000000000334700 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    417,401 ( 0.09%)  ???:0x000000000040a750 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    405,757 ( 0.09%)  ???:0x00000000002c9050 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    400,940 ( 0.09%)  ???:0x0000000000129120 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    400,295 ( 0.09%)  ???:0x0000000000292050 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    399,217 ( 0.09%)  ???:0x00000000002c8ec0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    398,677 ( 0.09%)  ???:0x000000000040b2a0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    389,660 ( 0.08%)  ???:0x0000000000203ac0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    387,571 ( 0.08%)  ???:0x00000000002c9c70 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    386,568 ( 0.08%)  ???:0x00000000002fdb80 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    384,938 ( 0.08%)  ???:0x00000000001b7ad0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    384,004 ( 0.08%)  ???:0x00000000003fe820 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    376,689 ( 0.08%)  ???:0x0000000000abaff0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    374,702 ( 0.08%)  ???:0x00000000003ae4c0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    374,664 ( 0.08%)  ???:0x00000000002ab400 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    374,551 ( 0.08%)  ???:0x0000000000e431b0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    366,435 ( 0.08%)  ???:0x0000000000a96df0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    360,006 ( 0.08%)  ???:0x0000000000be0cb0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    359,043 ( 0.08%)  ???:0x00000000002fee30 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    357,512 ( 0.08%)  ???:0x00000000002fd510 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    357,437 ( 0.08%)  ???:0x0000000000aafdf0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    355,949 ( 0.08%)  ???:0x0000000000a78a60 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    353,989 ( 0.08%)  ???:0x0000000000e3a760 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    352,853 ( 0.08%)  ???:0x00000000009d4c40 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    350,067 ( 0.08%)  ???:0x000000000013edf0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    347,735 ( 0.08%)  ???:0x000000000033cda0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    344,308 ( 0.07%)  ???:0x000000000012afc0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    342,800 ( 0.07%)  ???:0x00000000002525e0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    341,199 ( 0.07%)  ???:0x00000000001bd8e0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    339,864 ( 0.07%)  ???:0x0000000000a874c0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    335,360 ( 0.07%)  ???:0x0000000000c01f80 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    335,040 ( 0.07%)  ???:0x0000000000b01fb0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    332,141 ( 0.07%)  ???:0x00000000002836c0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    328,340 ( 0.07%)  ???:0x000000000034e700 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    327,969 ( 0.07%)  ???:0x0000000000e3aa90 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    322,408 ( 0.07%)  ???:0x0000000000292910 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    319,036 ( 0.07%)  ???:0x0000000000deb120 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    317,922 ( 0.07%)  ???:0x00000000001212c6 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    317,595 ( 0.07%)  ???:0x000000000013cfc0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    314,898 ( 0.07%)  ???:0x0000000000c64740 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    314,864 ( 0.07%)  ???:0x0000000000366eb0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    313,650 ( 0.07%)  ???:0x0000000000deb130 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    311,334 ( 0.07%)  ./libio/./libio/genops.c:_IO_default_xsputn [/usr/lib/x86_64-linux-gnu/libc.so.6]
#    309,398 ( 0.07%)  ???:0x00000000002fcf90 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    308,278 ( 0.07%)  ???:0x000000000033da60 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    307,253 ( 0.07%)  ???:0x000000000024b3d0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    301,359 ( 0.07%)  ???:0x00000000009d4c40'2 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    300,406 ( 0.07%)  ???:0x00000000003a9e10 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    298,793 ( 0.06%)  ???:0x0000000000451050 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    293,390 ( 0.06%)  ???:0x0000000000dd90c0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    292,716 ( 0.06%)  ???:0x0000000000bdca20 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    291,296 ( 0.06%)  ???:0x0000000000368640 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    284,828 ( 0.06%)  ???:0x000000000037c1b0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    278,679 ( 0.06%)  ???:0x0000000000395300 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    277,240 ( 0.06%)  ???:0x00000000009e6fb0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    275,355 ( 0.06%)  ???:0x0000000000369470 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    275,353 ( 0.06%)  ???:0x0000000000aafba0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    274,617 ( 0.06%)  ???:0x00000000002ff770 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    274,295 ( 0.06%)  ???:0x00000000002699d0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    274,036 ( 0.06%)  ???:0x0000000000aa3cb0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    270,460 ( 0.06%)  ???:0x0000000000bfa630 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    269,427 ( 0.06%)  ???:0x0000000000e3c8e0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    268,729 ( 0.06%)  ???:0x000000000015bb20 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    265,595 ( 0.06%)  ???:0x0000000000b58a60 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    265,591 ( 0.06%)  ???:0x000000000036a410 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    265,587 ( 0.06%)  ???:0x0000000000c665a0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    264,561 ( 0.06%)  ./string/../sysdeps/x86_64/strcmp.S:strcmp [/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2]
#    260,952 ( 0.06%)  ???:0x0000000000247590 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    260,588 ( 0.06%)  ???:0x0000000000bac6a0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    259,220 ( 0.06%)  ???:0x0000000000aad5e0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    258,845 ( 0.06%)  ???:0x0000000000368460 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    258,842 ( 0.06%)  ???:0x000000000029db60 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    255,089 ( 0.06%)  ???:0x0000000000bde170 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    254,986 ( 0.06%)  ???:0x00000000003a1fa0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    253,627 ( 0.05%)  ???:0x00000000003a2830 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    253,374 ( 0.05%)  ???:0x00000000002a2320 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    252,623 ( 0.05%)  ???:0x000000000033b530 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    250,348 ( 0.05%)  ./elf/./elf/dl-lookup.c:check_match [/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2]
#    246,046 ( 0.05%)  ???:0x0000000000a80e40 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    244,258 ( 0.05%)  ???:0x000000000013f3f0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    244,099 ( 0.05%)  ???:0x0000000000119957 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    242,820 ( 0.05%)  ???:0x0000000000247f90 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    241,549 ( 0.05%)  ???:0x0000000000aa5620 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    241,428 ( 0.05%)  ???:0x00000000002ba6d0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    240,944 ( 0.05%)  ???:0x0000000000396c60 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    240,652 ( 0.05%)  ???:0x000000000029cb50 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    239,520 ( 0.05%)  ./libio/./libio/strops.c:_IO_str_init_static_internal [/usr/lib/x86_64-linux-gnu/libc.so.6]
#    239,114 ( 0.05%)  ???:0x0000000000aab870 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    235,207 ( 0.05%)  ???:0x0000000000bf57e0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    234,446 ( 0.05%)  ???:0x0000000000aa8490 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    232,548 ( 0.05%)  ???:0x0000000000aa0da0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    230,248 ( 0.05%)  ???:0x0000000000bffe50 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    230,166 ( 0.05%)  ???:0x0000000000247fd0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    228,810 ( 0.05%)  ???:0x000000000024afc0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    228,409 ( 0.05%)  ???:0x000000000026e620 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    227,938 ( 0.05%)  ???:0x0000000000234a90 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    226,429 ( 0.05%)  ???:0x0000000000265920 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    226,255 ( 0.05%)  ???:0x0000000000a98750 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    223,038 ( 0.05%)  ???:0x0000000000aa35a0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    219,964 ( 0.05%)  ???:0x000000000028db90 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    219,615 ( 0.05%)  ???:0x00000000002d2720 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    219,146 ( 0.05%)  ???:0x00000000003ae660 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    216,340 ( 0.05%)  ???:0x0000000000339500 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    215,754 ( 0.05%)  ???:0x0000000000b54eb0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    215,288 ( 0.05%)  ???:0x00000000009ed140 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    211,296 ( 0.05%)  ???:0x0000000000a885a0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    211,052 ( 0.05%)  ???:0x0000000000b57e70 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    209,576 ( 0.05%)  ???:0x0000000000c004b0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    208,470 ( 0.05%)  ???:0x0000000000a50e10 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    206,494 ( 0.04%)  ???:0x0000000000a50ea0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    205,110 ( 0.04%)  ???:0x0000000000b59d40 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    204,001 ( 0.04%)  ???:0x0000000000396c70 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    203,962 ( 0.04%)  ???:0x00000000003b0c00 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    203,833 ( 0.04%)  ???:0x00000000002cf390 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    202,143 ( 0.04%)  ???:0x00000000001fe2e0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    201,694 ( 0.04%)  ???:0x000000000032f5e0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    201,031 ( 0.04%)  ???:0x00000000002d22f0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    200,991 ( 0.04%)  ???:0x0000000000e39140 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    198,999 ( 0.04%)  ???:0x00000000009d4df0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    198,775 ( 0.04%)  ???:0x0000000000bfd530 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    198,674 ( 0.04%)  ???:0x0000000000a5d6a0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    198,117 ( 0.04%)  ???:0x00000000002450d0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    196,616 ( 0.04%)  ???:0x0000000000146240 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    196,478 ( 0.04%)  ???:0x000000000024ae50 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    196,474 ( 0.04%)  ???:0x00000000001fe830 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    195,264 ( 0.04%)  ???:0x0000000000248000 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    194,445 ( 0.04%)  ???:0x000000000024db00 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    193,886 ( 0.04%)  ???:0x0000000000304aa0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    193,179 ( 0.04%)  ???:0x000000000033b4a0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    191,672 ( 0.04%)  ???:0x0000000000b46960 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    189,779 ( 0.04%)  ???:0x00000000003ab260 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    187,170 ( 0.04%)  ???:0x0000000000b91d20 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    187,124 ( 0.04%)  ???:0x0000000000af90c0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    187,064 ( 0.04%)  ???:0x0000000000a81b40 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    185,687 ( 0.04%)  ???:0x000000000013bf00 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    185,544 ( 0.04%)  ???:0x0000000000dbcf60 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    184,257 ( 0.04%)  ???:0x0000000000a5fe60 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    183,296 ( 0.04%)  ???:0x00000000002b8b00'2 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    181,839 ( 0.04%)  ???:0x000000000024c2e0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    181,609 ( 0.04%)  ???:0x0000000000ac6dc0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    181,557 ( 0.04%)  ???:0x0000000000bd0070 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    181,408 ( 0.04%)  ???:0x00000000002ff9f0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    180,708 ( 0.04%)  ???:0x0000000000b97340 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    180,686 ( 0.04%)  ???:0x00000000002cbd00 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    179,590 ( 0.04%)  ???:0x0000000000e46f20 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    178,992 ( 0.04%)  ???:0x00000000003aed80 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    178,950 ( 0.04%)  ???:0x00000000002fca60 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    178,105 ( 0.04%)  ???:0x0000000000292880 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    177,855 ( 0.04%)  ???:0x00000000002fe030 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    176,930 ( 0.04%)  ???:0x0000000000291ef0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    176,764 ( 0.04%)  ???:0x00000000009d4580 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    176,360 ( 0.04%)  ???:0x00000000001fe7f0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    175,952 ( 0.04%)  ???:0x0000000000e3a9b0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    174,272 ( 0.04%)  ???:0x000000000013c310 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    173,915 ( 0.04%)  ???:0x000000000013fda0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    172,367 ( 0.04%)  ???:0x0000000000bddd00 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    171,898 ( 0.04%)  ???:0x00000000003ac5a0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    171,753 ( 0.04%)  ???:0x00000000001924f0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    171,553 ( 0.04%)  ???:0x0000000000bf5470 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    170,603 ( 0.04%)  ???:0x0000000000290e70 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    170,288 ( 0.04%)  ???:0x000000000027da40'2 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    168,797 ( 0.04%)  ???:0x0000000000c66590 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    168,435 ( 0.04%)  ???:0x0000000000a45c20 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    167,376 ( 0.04%)  ???:0x00000000003038b0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    167,328 ( 0.04%)  ???:0x00000000003a9d30 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    167,043 ( 0.04%)  ???:0x00000000001605d0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    165,899 ( 0.04%)  ???:0x0000000000246f90 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    164,792 ( 0.04%)  ???:0x0000000000b94e50 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    163,573 ( 0.04%)  ???:0x0000000000354cc0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    163,016 ( 0.04%)  ???:0x0000000000250200 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    162,196 ( 0.04%)  ???:0x00000000002bcd50 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    161,625 ( 0.03%)  ???:0x0000000000223f30 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    161,019 ( 0.03%)  ???:0x00000000001931b0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    158,871 ( 0.03%)  ???:0x0000000000b56a80 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    158,367 ( 0.03%)  ???:0x000000000023e310 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    158,313 ( 0.03%)  ???:0x000000000024a710 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    157,066 ( 0.03%)  ???:0x0000000000291940 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    156,946 ( 0.03%)  ???:0x000000000033fa70 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    155,787 ( 0.03%)  ???:0x00000000001b6c70 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    155,781 ( 0.03%)  ???:0x0000000000bf2b10 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    155,148 ( 0.03%)  ???:0x0000000000b41690 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    154,701 ( 0.03%)  ???:0x0000000000b41ae0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    153,796 ( 0.03%)  ???:0x0000000000404510 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    153,124 ( 0.03%)  ???:0x0000000000dc0a10 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    151,892 ( 0.03%)  ???:0x0000000000421020 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    151,132 ( 0.03%)  ???:0x0000000000a242b0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    151,064 ( 0.03%)  ???:0x00000000003ae2b0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    150,948 ( 0.03%)  ???:0x0000000000291b20 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    150,800 ( 0.03%)  ???:0x0000000000c5ba90 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    150,743 ( 0.03%)  ???:0x0000000000335a70 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    150,507 ( 0.03%)  ???:0x0000000000421dd0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#    149,472 ( 0.03%)  ???:0x00000000003fe8f0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    148,960 ( 0.03%)  ./libio/./libio/genops.c:_IO_sputbackc [/usr/lib/x86_64-linux-gnu/libc.so.6]
#    148,639 ( 0.03%)  ???:0x000000000033bee0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    148,336 ( 0.03%)  ???:0x0000000000a15f80 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    148,164 ( 0.03%)  ???:0x00000000003e1b90 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    146,848 ( 0.03%)  ???:0x0000000000e46f30 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    146,763 ( 0.03%)  ???:0x0000000000256ea0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    145,920 ( 0.03%)  ./elf/../sysdeps/generic/dl-hash.h:do_lookup_x
#    145,882 ( 0.03%)  ???:0x0000000000aa38a0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    145,513 ( 0.03%)  ???:0x0000000000c666f0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    145,478 ( 0.03%)  ???:0x000000000029c260 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    145,137 ( 0.03%)  ???:0x000000000027da40 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    144,794 ( 0.03%)  ???:0x00000000009d6b90 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    143,797 ( 0.03%)  ???:0x0000000000368370 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    143,792 ( 0.03%)  ???:0x00000000009d4840 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    142,374 ( 0.03%)  ???:0x000000000027dac0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    142,009 ( 0.03%)  ???:0x000000000015b760 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    141,963 ( 0.03%)  ???:0x000000000040aad0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    141,247 ( 0.03%)  ???:0x000000000033a990 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    140,860 ( 0.03%)  ???:0x00000000003add50 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    140,375 ( 0.03%)  ???:0x00000000002cd8b0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    139,164 ( 0.03%)  ???:0x0000000000a60670 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    138,888 ( 0.03%)  ???:0x00000000002addf0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    138,722 ( 0.03%)  ???:0x0000000000b81030 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    137,534 ( 0.03%)  ???:0x0000000000b45b80 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#    137,491 ( 0.03%)  ???:0x00000000003733e0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
# ...
#     10,628 ( 0.00%)  ???:0x0000000000247ef0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#     10,605 ( 0.00%)  ???:0x0000000000e46750 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#     10,546 ( 0.00%)  ???:0x0000000004bb94d0 [???]
#     10,524 ( 0.00%)  ???:0x00000000002148e0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#     10,512 ( 0.00%)  ???:0x0000000000c4c310 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#     10,418 ( 0.00%)  ???:0x0000000000b54fc0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#     10,402 ( 0.00%)  ???:0x0000000000365930 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#     10,393 ( 0.00%)  ???:0x0000000000335e70 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#     10,372 ( 0.00%)  ???:std::istreambuf_iterator<char, std::char_traits<char> > std::num_get<char, std::istreambuf_iterator<char, std::char_traits<char> > >::_M_extract_int<long>(std::istreambuf_iterator<char, std::char_traits<char> >, std::istreambuf_iterator<char, std::char_traits<char> >, std::ios_base&, std::_Ios_Iostate&, long&) const [/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.30]
#     10,293 ( 0.00%)  ???:0x0000000000e44b10 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#     10,272 ( 0.00%)  ???:0x0000000000b3f020 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#     10,267 ( 0.00%)  ???:0x000000000000bed0 [/usr/lib/wsl/lib/libcuda.so.1]
#     10,257 ( 0.00%)  ???:0x00000000002cf880 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#     10,249 ( 0.00%)  ???:0x00000000002326c0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#     10,240 ( 0.00%)  ./wcsmbs/./wcsmbs/btowc.c:btowc [/usr/lib/x86_64-linux-gnu/libc.so.6]
#     10,239 ( 0.00%)  ???:0x0000000000b761a0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#     10,179 ( 0.00%)  ???:0x0000000000427e80 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#     10,171 ( 0.00%)  ???:0x0000000000b51ea0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#     10,164 ( 0.00%)  ???:0x000000000029b880 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#     10,126 ( 0.00%)  ???:0x000000000029e120 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#     10,101 ( 0.00%)  ???:0x0000000000abb090 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#     10,052 ( 0.00%)  ???:0x0000000000254030 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#     10,042 ( 0.00%)  ./malloc/./malloc/malloc.c:sysmalloc [/usr/lib/x86_64-linux-gnu/libc.so.6]
#     10,036 ( 0.00%)  ???:0x00000000002d2190 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#     10,021 ( 0.00%)  ???:0x0000000000e43eb0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#     10,009 ( 0.00%)  ???:0x0000000000b51070 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,994 ( 0.00%)  ./malloc/./malloc/malloc.c:realloc [/usr/lib/x86_64-linux-gnu/libc.so.6]
#      9,948 ( 0.00%)  ???:0x00000000003967f0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,936 ( 0.00%)  ???:0x0000000000308ec0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#      9,926 ( 0.00%)  ???:0x0000000000368ad0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,901 ( 0.00%)  ???:0x0000000000204bb0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#      9,880 ( 0.00%)  ???:0x00000000002fce80 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,872 ( 0.00%)  ???:0x0000000000143300 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,858 ( 0.00%)  ???:0x00000000001ff000 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#      9,840 ( 0.00%)  ???:0x0000000000af8970 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,798 ( 0.00%)  ./stdlib/./stdlib/msort.c:qsort_r [/usr/lib/x86_64-linux-gnu/libc.so.6]
#      9,771 ( 0.00%)  ???:0x00000000003f98a0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#      9,744 ( 0.00%)  ???:0x0000000000342000 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,738 ( 0.00%)  ???:0x00000000001a0d70 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,723 ( 0.00%)  ./string/../sysdeps/x86_64/multiarch/strchr-avx2.S:__strchr_avx2 [/usr/lib/x86_64-linux-gnu/libc.so.6]
#      9,656 ( 0.00%)  ???:0x00000000001dcac0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,649 ( 0.00%)  ???:0x00000000002c8d60 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,647 ( 0.00%)  ???:0x0000000000291f80 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,643 ( 0.00%)  ???:0x00000000003a4490 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,608 ( 0.00%)  ???:0x0000000000163cb0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,601 ( 0.00%)  ???:0x00000000001bead0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#      9,593 ( 0.00%)  ???:0x0000000000b803d0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,592 ( 0.00%)  ???:0x00000000002ff570 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,568 ( 0.00%)  ???:0x000000000013c7d0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,565 ( 0.00%)  ???:0x0000000000aa7ba0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,515 ( 0.00%)  ???:0x00000000009e8570 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,514 ( 0.00%)  ???:0x00000000002451f0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,504 ( 0.00%)  ???:0x0000000000c4f530 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,494 ( 0.00%)  ???:0x00000000002af830 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,490 ( 0.00%)  ???:0x000000000013f860 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,472 ( 0.00%)  ???:0x000000000029da80 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,456 ( 0.00%)  ???:0x000000000014d940 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,440 ( 0.00%)  ???:0x0000000000c31960 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,415 ( 0.00%)  ???:0x00000000002abac0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,392 ( 0.00%)  ???:0x00000000003aaa90 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,384 ( 0.00%)  ???:0x0000000000ab5d20 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,377 ( 0.00%)  ???:0x00000000001fe4c0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,367 ( 0.00%)  ???:0x0000000000167970 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,314 ( 0.00%)  ???:0x0000000000beab10 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,289 ( 0.00%)  ???:0x0000000000e39d70 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,241 ( 0.00%)  ???:0x00000000002a9ec0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,212 ( 0.00%)  ???:0x0000000000db6d10 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,185 ( 0.00%)  ???:0x000000000024d060 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,139 ( 0.00%)  ???:0x000000000029baf0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,138 ( 0.00%)  ???:0x0000000000333d70 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,108 ( 0.00%)  ???:0x00000000002ccb70 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,097 ( 0.00%)  ???:0x00000000001a7e70 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#      9,078 ( 0.00%)  ???:0x0000000000166100 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,065 ( 0.00%)  ./string/../sysdeps/x86_64/multiarch/memmove-vec-unaligned-erms.S:__mempcpy_avx_unaligned_erms [/usr/lib/x86_64-linux-gnu/libc.so.6]
#      9,040 ( 0.00%)  ???:0x0000000000161620'2 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      9,020 ( 0.00%)  ???:0x0000000000b82330 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,994 ( 0.00%)  ???:0x0000000000145fa0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,956 ( 0.00%)  ???:0x0000000000121383 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#      8,932 ( 0.00%)  ./elf/./elf/dl-runtime.c:_dl_fixup [/usr/lib/x86_64-linux-gnu/ld-linux-x86-64.so.2]
#      8,928 ( 0.00%)  ???:0x0000000000117c97 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#      8,928 ( 0.00%)  ???:0x0000000000117cc6 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#      8,928 ( 0.00%)  ???:0x0000000000117cf5 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#      8,920 ( 0.00%)  ???:0x0000000000dec150 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,901 ( 0.00%)  ???:0x00000000002cdd90 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,890 ( 0.00%)  ???:0x00000000003aaaf0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,880 ( 0.00%)  ???:0x00000000003b0ff0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,880 ( 0.00%)  ???:0x00000000003b1150 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,878 ( 0.00%)  ???:0x000000000014b560 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libcuda.so.1.1]
#      8,817 ( 0.00%)  ???:0x0000000000a88c10 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,796 ( 0.00%)  ???:0x0000000000e2a750 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,743 ( 0.00%)  ???:0x0000000000b53430 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,740 ( 0.00%)  ???:0x0000000000257650 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,726 ( 0.00%)  ???:0x000000000033d450 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,704 ( 0.00%)  ???:0x00000000002a1c90 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,700 ( 0.00%)  ???:0x0000000000b8e9d0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,687 ( 0.00%)  ???:0x0000000000b41040 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,684 ( 0.00%)  ???:0x0000000000ab9d60 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,682 ( 0.00%)  ???:0x000000000024ab80 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,679 ( 0.00%)  ???:0x0000000000299b60 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,616 ( 0.00%)  ???:0x0000000000abba50 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,570 ( 0.00%)  ???:0x000000000023bd30 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,568 ( 0.00%)  ???:0x0000000000b4edb0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#      8,540 ( 0.00%)  ???:0x000000000030dde0 [/usr/lib/wsl/drivers/nvdmi.inf_amd64_3d50ed78ef5da3d8/libnvidia-ptxjitcompiler.so.1]
#
# --------------------------------------------------------------------------------
# -- User-annotated source: exaustiva_thrust.cu
# --------------------------------------------------------------------------------
#   No information has been collected for exaustiva_thrust.cu
#
# --------------------------------------------------------------------------------
# The following files chosen for auto-annotation could not be found:
# --------------------------------------------------------------------------------
#   ./ctype/./ctype/ctype.c
#   ./dlfcn/./dlfcn/dlerror.c
#   ./dlfcn/./dlfcn/dlsym.c
#   ./elf/../sysdeps/generic/dl-hash.h
#   ./elf/../sysdeps/generic/dl-protected.h
#   ./elf/../sysdeps/generic/ldsodefs.h
#   ./elf/../sysdeps/x86_64/dl-machine.h
#   ./elf/./elf/dl-addr.c
#   ./elf/./elf/dl-deps.c
#   ./elf/./elf/dl-error-skeleton.c
#   ./elf/./elf/dl-load.c
#   ./elf/./elf/dl-lookup.c
#   ./elf/./elf/dl-misc.c
#   ./elf/./elf/dl-runtime.c
#   ./elf/./elf/dl-sym.c
#   ./elf/./elf/dl-tunables.c
#   ./elf/./elf/dl-version.c
#   ./elf/./elf/do-rel.h
#   ./iconv/../iconv/skeleton.c
#   ./libio/./libio/genops.c
#   ./libio/./libio/iogetdelim.c
#   ./libio/./libio/iovsprintf.c
#   ./libio/./libio/libioP.h
#   ./libio/./libio/strops.c
#   ./libio/./libio/vsnprintf.c
#   ./malloc/./malloc/arena.c
#   ./malloc/./malloc/malloc.c
#   ./malloc/./malloc/scratch_buffer_set_array_size.c
#   ./math/../sysdeps/ieee754/dbl-64/e_pow.c
#   ./math/./math/w_pow_compat.c
#   ./nptl/./nptl/libc-cleanup.c
#   ./nptl/./nptl/pthread_getspecific.c
#   ./nptl/./nptl/pthread_mutex_init.c
#   ./nptl/./nptl/pthread_mutex_lock.c
#   ./nptl/./nptl/pthread_mutex_unlock.c
#   ./nptl/./nptl/pthread_rwlock_common.c
#   ./nptl/./nptl/pthread_rwlock_unlock.c
#   ./nptl/./nptl/pthread_rwlock_wrlock.c
#   ./setjmp/../sysdeps/x86_64/setjmp.S
#   ./stdio-common/../include/scratch_buffer.h
#   ./stdio-common/../libio/libioP.h
#   ./stdio-common/../libio/strfile.h
#   ./stdio-common/./stdio-common/_itoa.c
#   ./stdio-common/./stdio-common/isoc99_sscanf.c
#   ./stdio-common/./stdio-common/printf-parse.h
#   ./stdio-common/./stdio-common/sprintf.c
#   ./stdio-common/./stdio-common/vfprintf-internal.c
#   ./stdio-common/./stdio-common/vfscanf-internal.c
#   ./stdlib/../stdlib/strtol.c
#   ./stdlib/../stdlib/strtol_l.c
#   ./stdlib/./stdlib/getenv.c
#   ./stdlib/./stdlib/msort.c
#   ./string/../sysdeps/x86_64/multiarch/memchr-avx2.S
#   ./string/../sysdeps/x86_64/multiarch/memmove-vec-unaligned-erms.S
#   ./string/../sysdeps/x86_64/multiarch/memset-vec-unaligned-erms.S
#   ./string/../sysdeps/x86_64/multiarch/strchr-avx2.S
#   ./string/../sysdeps/x86_64/multiarch/strcmp-avx2.S
#   ./string/../sysdeps/x86_64/multiarch/strcpy-avx2.S
#   ./string/../sysdeps/x86_64/multiarch/strlen-avx2.S
#   ./string/../sysdeps/x86_64/strcmp.S
#   ./wcsmbs/./wcsmbs/btowc.c
#   ./wcsmbs/./wcsmbs/wcrtomb.c

# %% [markdown]
# ## Análise de desempenho
#
# ### Questões gerais sobre o desempenho dos programas
#
# O output do *Valgrind* sugere que ambos os programas tem problemas de vazamento de memória. Esse erro ocorre provavelmente por conta da falta de desalocação de um recurso de memória.
#
# Além disso, para a estratégia aleatória, outras indicações mostram um grande número de operações de alocação e liberação de memória em funções que são chamadas várias vezes no decorrer do programa, como std::chrono::system_clock::now().time_since_epoch().count(), std::default_random_engine generator, std::binomial_distribution<int> distribution e srand(time(NULL)), o que pode ser otimizado se for possível reduzir a quantidade de chamadas dessas funções.
#
# Outra questão que pode ser melhorada é a alocação dinâmica de memória.
#
#
# ### Análise de desempenho do programa aleatório
#
# Temos também, no modelo aleatório, um loop que serva para fazer uma lista apenas com filmes que estão disponíveis no horário atual. Esse consome bastante, apesar de ser um grande trade-off entre ficar apenas procurando um filme de forma aleatória, e é algo que pode ser melhorado, comparando mais casos.
#
# ### Análise de desempenho do programa guloso
#
# O programa guloso possui muitas melhorias que podem ser feitas, como a alocação dinâmica de memória, a redução do número de alocações e liberações.

# %% [markdown]
# ## Comparações com base em dados de desempenho

# %% [markdown]
# Antes, é importante realizar o entendimento a seguir:
#
# ### Arquivos de Input
#
# Todos os arquivos de input possuem 100 categorias.
#
# - **input-1k.txt**: contém 1000 filmes.
# - **input-10k.txt**: contém 10000 filmes.
# - **input-100k.txt**: contém 100000 filmes.
# - **input-1m.txt**: contém 1000000 filmes.
# - **input-10m.txt**: contém 10000000 filmes.
# - **input-100m.txt**: contém 100000000 filmes.
#
# ### Compilação
#
# - g++ -Wall -O3 -g gulosa.cpp -o gulosa
# - g++ -Wall -O3 -g aleatoriedade.cpp -o aleatoriedade
#
# ### Execução
#
# Exemplos:
# - ./gulosa inputs/< input-1k.txt > outputs/output-gulosa-1k.txt
# - ./aleatoriedade inputs/< input-1k.txt > outputs/output-aleatoriedade-1k.txt

# %% [markdown]
# - Importando bibliotecas

# %%
import time
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# - Criando uma estrutura de dados para armazenar os dados de cada execução

# %%
data = {
    'gulosa' : {
        'input-1k.txt': {
            'tempo': [],
            'memoria': []
        },
        'input-10k.txt': {
            'tempo': [],
            'memoria': []
        },
        'input-100k.txt': {
            'tempo': [],
            'memoria': []
        },
        'input-1m.txt': {
            'tempo': [],
            'memoria': []
        },
        'input-10m.txt': {
            'tempo': [],
            'memoria': []
        },
        'input-100m.txt': {
            'tempo': [],
            'memoria': []
        },
    },
    'aleatoriedade': {
        'input-1k.txt': {
            'tempo': [],
            'memoria': []
        },
        'input-10k.txt': {
            'tempo': [],
            'memoria': []
        },
        'input-100k.txt': {
            'tempo': [],
            'memoria': []
        },
        'input-1m.txt': {
            'tempo': [],
            'memoria': []
        },
        'input-10m.txt': {
            'tempo': [],
            'memoria': []
        },
        'input-100m.txt': {
            'tempo': [],
            'memoria': []
        },
    }
}

# %% [markdown]
# - Funções auxiliares

# %%
def number_of_movies(file):
    with open(file, 'r') as f:
        line = f.readline().split()
        return int(line[0])

# %% [markdown]
# - Realizando o loop para cada arquivo de input e cada algoritmo
#
# Abaixo, serão realizadas 10 interações para cada arquivo de input e cada algoritmo, e os resultados serão salvos em um arquivo de texto logo após.

# %%
for algoritmo in data:
    for arquivo in data[algoritmo]:
        for i in range(10):
            print(f'{algoritmo} - {arquivo} - {i+1}/10')
            output_name = str(i) + '_' + arquivo.split('-')[1]
            start_time = time.time()
            # !./{algoritmo} < inputs/{arquivo} > outputs/{algoritmo}_output_{output_name}
            end_time = time.time() - start_time
            print('\tTime:', end_time)
            data[algoritmo][arquivo]['tempo'].append(end_time)
            data[algoritmo][arquivo]['memoria'].append(number_of_movies(f'outputs/{algoritmo}_output_{output_name}'))
# Out:
# gulosa - input-1k.txt - 1/10
# 	Time: 0.24486780166625977
# gulosa - input-1k.txt - 2/10
# 	Time: 0.21976161003112793
# gulosa - input-1k.txt - 3/10
# 	Time: 0.2172715663909912
# gulosa - input-1k.txt - 4/10
# 	Time: 0.21760320663452148
# gulosa - input-1k.txt - 5/10
# 	Time: 0.2209932804107666
# gulosa - input-1k.txt - 6/10
# 	Time: 0.21934962272644043
# gulosa - input-1k.txt - 7/10
# 	Time: 0.2175154685974121
# gulosa - input-1k.txt - 8/10
# 	Time: 0.21622538566589355
# gulosa - input-1k.txt - 9/10
# 	Time: 0.21704697608947754
# gulosa - input-1k.txt - 10/10
# 	Time: 0.21761488914489746
# gulosa - input-10k.txt - 1/10
# 	Time: 0.22706341743469238
# gulosa - input-10k.txt - 2/10
# 	Time: 0.22724509239196777
# gulosa - input-10k.txt - 3/10
# 	Time: 0.2231128215789795
# gulosa - input-10k.txt - 4/10
# 	Time: 0.22176027297973633
# gulosa - input-10k.txt - 5/10
# 	Time: 0.22248315811157227
# gulosa - input-10k.txt - 6/10
# 	Time: 0.22214937210083008
# gulosa - input-10k.txt - 7/10
# 	Time: 0.22198748588562012
# gulosa - input-10k.txt - 8/10
# 	Time: 0.22265315055847168
# gulosa - input-10k.txt - 9/10
# 	Time: 0.2220168113708496
# gulosa - input-10k.txt - 10/10
# 	Time: 0.22414898872375488
# gulosa - input-100k.txt - 1/10
# 	Time: 0.2758166790008545
# gulosa - input-100k.txt - 2/10
# 	Time: 0.27362656593322754
# gulosa - input-100k.txt - 3/10
# 	Time: 0.27460598945617676
# gulosa - input-100k.txt - 4/10
# 	Time: 0.275437593460083
# gulosa - input-100k.txt - 5/10
# 	Time: 0.274733304977417
# gulosa - input-100k.txt - 6/10
# 	Time: 0.2767963409423828
# gulosa - input-100k.txt - 7/10
# 	Time: 0.2756931781768799
# gulosa - input-100k.txt - 8/10
# 	Time: 0.27451300621032715
# gulosa - input-100k.txt - 9/10
# 	Time: 0.2743678092956543
# gulosa - input-100k.txt - 10/10
# 	Time: 0.2759995460510254
# gulosa - input-1m.txt - 1/10
# 	Time: 0.8363964557647705
# gulosa - input-1m.txt - 2/10
# 	Time: 0.825068473815918
# gulosa - input-1m.txt - 3/10
# 	Time: 0.826446533203125
# gulosa - input-1m.txt - 4/10
# 	Time: 0.82491135597229
# gulosa - input-1m.txt - 5/10
# 	Time: 0.8424804210662842
# gulosa - input-1m.txt - 6/10
# 	Time: 0.8289234638214111
# gulosa - input-1m.txt - 7/10
# 	Time: 0.8277044296264648
# gulosa - input-1m.txt - 8/10
# 	Time: 0.8355064392089844
# gulosa - input-1m.txt - 9/10
# 	Time: 0.8259677886962891
# gulosa - input-1m.txt - 10/10
# 	Time: 0.822930097579956
# gulosa - input-10m.txt - 1/10
# 	Time: 6.227790832519531
# gulosa - input-10m.txt - 2/10
# 	Time: 6.160993576049805
# gulosa - input-10m.txt - 3/10
# 	Time: 6.1006224155426025
# gulosa - input-10m.txt - 4/10
# 	Time: 6.227593183517456
# gulosa - input-10m.txt - 5/10
# 	Time: 6.108613014221191
# gulosa - input-10m.txt - 6/10
# 	Time: 6.100232124328613
# gulosa - input-10m.txt - 7/10
# 	Time: 6.150695323944092
# gulosa - input-10m.txt - 8/10
# 	Time: 6.152300834655762
# gulosa - input-10m.txt - 9/10
# 	Time: 6.104461193084717
# gulosa - input-10m.txt - 10/10
# 	Time: 6.101189136505127
# gulosa - input-100m.txt - 1/10
# 	Time: 31.796712636947632
# gulosa - input-100m.txt - 2/10
# 	Time: 31.603301525115967
# gulosa - input-100m.txt - 3/10
# 	Time: 31.59065580368042
# gulosa - input-100m.txt - 4/10
# 	Time: 31.678860664367676
# gulosa - input-100m.txt - 5/10
# 	Time: 31.53930974006653
# gulosa - input-100m.txt - 6/10
# 	Time: 31.607511520385742
# gulosa - input-100m.txt - 7/10
# 	Time: 31.543062210083008
# gulosa - input-100m.txt - 8/10
# 	Time: 31.61630654335022
# gulosa - input-100m.txt - 9/10
# 	Time: 31.59719443321228
# gulosa - input-100m.txt - 10/10
# 	Time: 31.5690495967865
# aleatoriedade - input-1k.txt - 1/10
# 	Time: 0.21631884574890137
# aleatoriedade - input-1k.txt - 2/10
# 	Time: 0.21664667129516602
# aleatoriedade - input-1k.txt - 3/10
# 	Time: 0.21693658828735352
# aleatoriedade - input-1k.txt - 4/10
# 	Time: 0.2167205810546875
# aleatoriedade - input-1k.txt - 5/10
# 	Time: 0.2157442569732666
# aleatoriedade - input-1k.txt - 6/10
# 	Time: 0.2157294750213623
# aleatoriedade - input-1k.txt - 7/10
# 	Time: 0.21889424324035645
# aleatoriedade - input-1k.txt - 8/10
# 	Time: 0.21556711196899414
# aleatoriedade - input-1k.txt - 9/10
# 	Time: 0.21933650970458984
# aleatoriedade - input-1k.txt - 10/10
# 	Time: 0.21633672714233398
# aleatoriedade - input-10k.txt - 1/10
# 	Time: 0.22184276580810547
# aleatoriedade - input-10k.txt - 2/10
# 	Time: 0.22275686264038086
# aleatoriedade - input-10k.txt - 3/10
# 	Time: 0.2259213924407959
# aleatoriedade - input-10k.txt - 4/10
# 	Time: 0.22508883476257324
# aleatoriedade - input-10k.txt - 5/10
# 	Time: 0.22524213790893555
# aleatoriedade - input-10k.txt - 6/10
# 	Time: 0.22473621368408203
# aleatoriedade - input-10k.txt - 7/10
# 	Time: 0.22108197212219238
# aleatoriedade - input-10k.txt - 8/10
# 	Time: 0.22069740295410156
# aleatoriedade - input-10k.txt - 9/10
# 	Time: 0.22317910194396973
# aleatoriedade - input-10k.txt - 10/10
# 	Time: 0.22114157676696777
# aleatoriedade - input-100k.txt - 1/10
# 	Time: 0.26997852325439453
# aleatoriedade - input-100k.txt - 2/10
# 	Time: 0.269533634185791
# aleatoriedade - input-100k.txt - 3/10
# 	Time: 0.2702901363372803
# aleatoriedade - input-100k.txt - 4/10
# 	Time: 0.27373528480529785
# aleatoriedade - input-100k.txt - 5/10
# 	Time: 0.27115559577941895
# aleatoriedade - input-100k.txt - 6/10
# 	Time: 0.27423739433288574
# aleatoriedade - input-100k.txt - 7/10
# 	Time: 0.2725706100463867
# aleatoriedade - input-100k.txt - 8/10
# 	Time: 0.27015209197998047
# aleatoriedade - input-100k.txt - 9/10
# 	Time: 0.27741241455078125
# aleatoriedade - input-100k.txt - 10/10
# 	Time: 0.27609896659851074
# aleatoriedade - input-1m.txt - 1/10
# 	Time: 0.7628722190856934
# aleatoriedade - input-1m.txt - 2/10
# 	Time: 0.81777024269104
# aleatoriedade - input-1m.txt - 3/10
# 	Time: 0.7689075469970703
# aleatoriedade - input-1m.txt - 4/10
# 	Time: 0.8146336078643799
# aleatoriedade - input-1m.txt - 5/10
# 	Time: 0.7619624137878418
# aleatoriedade - input-1m.txt - 6/10
# 	Time: 0.7653868198394775
# aleatoriedade - input-1m.txt - 7/10
# 	Time: 0.807565450668335
# aleatoriedade - input-1m.txt - 8/10
# 	Time: 0.769071102142334
# aleatoriedade - input-1m.txt - 9/10
# 	Time: 0.7631161212921143
# aleatoriedade - input-1m.txt - 10/10
# 	Time: 0.8104696273803711
# aleatoriedade - input-10m.txt - 1/10
# 	Time: 5.422248125076294
# aleatoriedade - input-10m.txt - 2/10
# 	Time: 5.44771409034729
# aleatoriedade - input-10m.txt - 3/10
# 	Time: 5.795228004455566
# aleatoriedade - input-10m.txt - 4/10
# 	Time: 5.408427000045776
# aleatoriedade - input-10m.txt - 5/10
# 	Time: 5.394083023071289
# aleatoriedade - input-10m.txt - 6/10
# 	Time: 5.514809608459473
# aleatoriedade - input-10m.txt - 7/10
# 	Time: 5.420584678649902
# aleatoriedade - input-10m.txt - 8/10
# 	Time: 5.555781602859497
# aleatoriedade - input-10m.txt - 9/10
# 	Time: 5.421240568161011
# aleatoriedade - input-10m.txt - 10/10
# 	Time: 5.468222141265869
# aleatoriedade - input-100m.txt - 1/10
# 	Time: 26.01672887802124
# aleatoriedade - input-100m.txt - 2/10
# 	Time: 25.329715728759766
# aleatoriedade - input-100m.txt - 3/10
# 	Time: 25.555400133132935
# aleatoriedade - input-100m.txt - 4/10
# 	Time: 25.187378406524658
# aleatoriedade - input-100m.txt - 5/10
# 	Time: 24.783406734466553
# aleatoriedade - input-100m.txt - 6/10
# 	Time: 24.63597011566162
# aleatoriedade - input-100m.txt - 7/10
# 	Time: 24.753344297409058
# aleatoriedade - input-100m.txt - 8/10
# 	Time: 25.129358768463135
# aleatoriedade - input-100m.txt - 9/10
# 	Time: 24.177751779556274
# aleatoriedade - input-100m.txt - 10/10
# 	Time: 24.21467161178589

# %% [markdown]
# - Salvando os resultados em um arquivo JSON para serem utilizados no gráfico em outro momento

# %%
import json

with open('data.json', 'w') as fp:
    json.dump(json.dumps(data, indent=2), fp)

# %% [markdown]
# - Gerando o DataFrame para ser utilizado no gráfico

# %%
df = pd.DataFrame(columns=['algoritmo', 'arquivo', 'tentativa', 'tempo', 'memoria'])

for algoritmo in data:
    for arquivo in data[algoritmo]:
        for i in range(10):
            df = pd.concat([df, pd.DataFrame({
                'algoritmo': [algoritmo],
                'arquivo': [arquivo],
                'tentativa': [i+1],
                'tempo': [data[algoritmo][arquivo]['tempo'][i]],
                'memoria': [data[algoritmo][arquivo]['memoria'][i]]
            })])

df
# Out:
#         algoritmo         arquivo tentativa      tempo memoria
# 0          gulosa    input-1k.txt         1   0.244868      22
# 0          gulosa    input-1k.txt         2   0.219762      22
# 0          gulosa    input-1k.txt         3   0.217272      22
# 0          gulosa    input-1k.txt         4   0.217603      22
# 0          gulosa    input-1k.txt         5   0.220993      22
# ..            ...             ...       ...        ...     ...
# 0   aleatoriedade  input-100m.txt         6  24.635970      23
# 0   aleatoriedade  input-100m.txt         7  24.753344      23
# 0   aleatoriedade  input-100m.txt         8  25.129359      23
# 0   aleatoriedade  input-100m.txt         9  24.177752      23
# 0   aleatoriedade  input-100m.txt        10  24.214672      23
#
# [120 rows x 5 columns]

# %% [markdown]
# - Salvando o DataFrame em um arquivo CSV

# %%
df.to_csv('data.csv', index=False)

# %%
df.head(10)
# Out:
#   algoritmo       arquivo tentativa     tempo memoria
# 0    gulosa  input-1k.txt         1  0.244868      22
# 0    gulosa  input-1k.txt         2  0.219762      22
# 0    gulosa  input-1k.txt         3  0.217272      22
# 0    gulosa  input-1k.txt         4  0.217603      22
# 0    gulosa  input-1k.txt         5  0.220993      22
# 0    gulosa  input-1k.txt         6  0.219350      22
# 0    gulosa  input-1k.txt         7  0.217515      22
# 0    gulosa  input-1k.txt         8  0.216225      22
# 0    gulosa  input-1k.txt         9  0.217047      22
# 0    gulosa  input-1k.txt        10  0.217615      22

# %% [markdown]
# ### Média de Tempo por arquivo por algoritmo

# %%
df_mean = df.groupby(['algoritmo', 'arquivo']).mean(numeric_only=True).reset_index()
df_mean
# Out:
#         algoritmo         arquivo      tempo
# 0   aleatoriedade  input-100k.txt   0.272516
# 1   aleatoriedade  input-100m.txt  24.978373
# 2   aleatoriedade   input-10k.txt   0.223169
# 3   aleatoriedade   input-10m.txt   5.484834
# 4   aleatoriedade    input-1k.txt   0.216823
# 5   aleatoriedade    input-1m.txt   0.784176
# 6          gulosa  input-100k.txt   0.275159
# 7          gulosa  input-100m.txt  31.614196
# 8          gulosa   input-10k.txt   0.223462
# 9          gulosa   input-10m.txt   6.143449
# 10         gulosa    input-1k.txt   0.220825
# 11         gulosa    input-1m.txt   0.829634

# %% [markdown]
# ### Gráfico de tempo

# %%
df_mean.sort_values(by=['tempo'], inplace=True)

# %%
fig, ax = plt.subplots(figsize=(10, 5))
for algoritmo in df_mean['algoritmo'].unique():
    df_aux = df_mean[df_mean['algoritmo'] == algoritmo]
    ax.plot(df_aux['arquivo'], df_aux['tempo'], label=algoritmo)

ax.set_title('Tempo por algoritmo por arquivo')
ax.set_xlabel('Arquivo')
ax.set_ylabel('Tempo (s)')
ax.legend()
plt.show()

# %% [markdown]
# Vemos que a estratégia aleatória possui uma vantagem maior quando temos um cenário de mais fimes no nosso arquivo de input.
#
# Isso deve-se ao fato de que a estratégia gulosa percorre todos os filmes até completar a Maratona de Filmes, procurando filmes que possam ser colocados nela. Já a estratégia aleatória, ao invés de percorrer todos os filmes, escolhe aleatoriamente um filme que pode ser colocado na Maratona de Filmes e o insere.

# %% [markdown]
# - Criando o Dataset para o gráfico de Filmes na Mochila vs Input

# %%
df_mean_movies = df.drop(columns=['tempo','tentativa'])
df_mean_movies = df_mean_movies.groupby(['algoritmo', 'arquivo']).mean().reset_index()
df_mean_movies
# Out:
#         algoritmo         arquivo  memoria
# 0   aleatoriedade  input-100k.txt     23.0
# 1   aleatoriedade  input-100m.txt     23.0
# 2   aleatoriedade   input-10k.txt     22.5
# 3   aleatoriedade   input-10m.txt     23.0
# 4   aleatoriedade    input-1k.txt     20.9
# 5   aleatoriedade    input-1m.txt     23.1
# 6          gulosa  input-100k.txt     24.0
# 7          gulosa  input-100m.txt     24.0
# 8          gulosa   input-10k.txt     24.0
# 9          gulosa   input-10m.txt     24.0
# 10         gulosa    input-1k.txt     22.0
# 11         gulosa    input-1m.txt     24.0

# %%
order_arquivos = list(data['gulosa'].keys())

df_mean_movies['arquivo'] = pd.Categorical(df_mean_movies['arquivo'], categories=order_arquivos, ordered=True)
df_mean_movies = df_mean_movies.sort_values(by=['arquivo'])
df_mean_movies
# Out:
#         algoritmo         arquivo  memoria
# 4   aleatoriedade    input-1k.txt     20.9
# 10         gulosa    input-1k.txt     22.0
# 2   aleatoriedade   input-10k.txt     22.5
# 8          gulosa   input-10k.txt     24.0
# 0   aleatoriedade  input-100k.txt     23.0
# 6          gulosa  input-100k.txt     24.0
# 5   aleatoriedade    input-1m.txt     23.1
# 11         gulosa    input-1m.txt     24.0
# 3   aleatoriedade   input-10m.txt     23.0
# 9          gulosa   input-10m.txt     24.0
# 1   aleatoriedade  input-100m.txt     23.0
# 7          gulosa  input-100m.txt     24.0

# %%
fig, ax = plt.subplots(figsize=(10, 5))

for algoritmo in df_mean_movies['algoritmo'].unique():
    df_aux = df_mean_movies[df_mean_movies['algoritmo'] == algoritmo]
    ax.plot(df_aux['arquivo'], df_aux['memoria'], label=algoritmo)

ax.set_title('Filmes por algoritmo por arquivo')
ax.set_xlabel('Arquivo')
ax.set_ylabel('Filmes (número de filmes)')
ax.legend()
plt.show()

# %% [markdown]
# Já no gráfico de Filmes na Mochila vs Input, vemos que a estratégia gulosa possui uma vantagem maior quando temos um cenário de mais fimes no nosso arquivo de input. Isso deve-se ao fato de que a estratégia gulosa percorre todos os filmes até completar a Maratona de Filmes, procurando filmes que possam ser colocados nela. Já a estratégia aleatória, ao invés de percorrer todos os filmes, escolhe aleatoriamente um filme que pode ser colocado na Maratona de Filmes e o insere no bitset.

# %% [markdown]
# ## Comparando categorias

# %% [markdown]
# Além disso, é possível comparar a quantidade de filmes por categoria que foram colocados na Maratona de Filmes.
#
# Neste caso, serão utilizados 10000 filmes variando a quantidade de categorias de 1,2,3,4,5 e 10,20,30,50 e 100.
#
# - **input-10k-1.txt**: contém 10000 filmes e 1 categoria.
# - **input-10k-2.txt**: contém 10000 filmes e 2 categorias.
# - **input-10k-3.txt**: contém 10000 filmes e 3 categorias.
# - **input-10k-4.txt**: contém 10000 filmes e 4 categorias.
# - **input-10k-5.txt**: contém 10000 filmes e 5 categorias.
# - **input-10k-10.txt**: contém 10000 filmes e 10 categorias.
# - **input-10k-20.txt**: contém 10000 filmes e 20 categorias.
# - **input-10k-30.txt**: contém 10000 filmes e 30 categorias.
# - **input-10k-50.txt**: contém 10000 filmes e 50 categorias.
# - **input-10k-100.txt**: contém 10000 filmes e 100 categorias.

# %%
data_categoria = {
    'gulosa' : {
        'input-10k-1.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-2.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-3.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-4.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-5.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-10.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-20.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-30.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-50.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-75.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-100.txt': {
            'temmpo': 0,
            'categoria': 0
        },
    },
    'aleatoriedade': {
        'input-10k-1.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-2.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-3.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-4.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-5.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-10.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-20.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-30.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-50.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-75.txt': {
            'temmpo': 0,
            'categoria': 0
        },
        'input-10k-100.txt': {
            'temmpo': 0,
            'categoria': 0
        },
    }
}

# %%
for algoritmo in data_categoria:
    for arquivo in data_categoria[algoritmo]:
        output_name = algoritmo + '_output_categoria_' + arquivo.split('-')[2]
        start_time = time.time()
        # !./{algoritmo} < inputs/{arquivo} > outputs/{output_name}
        end_time = time.time() - start_time
        print('\tTime:', end_time)
        data_categoria[algoritmo][arquivo]['tempo'] = end_time
        data_categoria[algoritmo][arquivo]['memoria'] = number_of_movies(f'outputs/{output_name}')
# Out:
# 	Time: 0.18789339065551758
# 	Time: 0.17771244049072266
# 	Time: 0.18178534507751465
# 	Time: 0.2030043601989746
# 	Time: 0.1878962516784668
# 	Time: 0.19562911987304688
# 	Time: 0.20332121849060059
# 	Time: 0.18252110481262207
# 	Time: 0.1889197826385498
# 	Time: 0.18184685707092285
# 	Time: 0.1851496696472168
# 	Time: 0.19526100158691406
# 	Time: 0.17992353439331055
# 	Time: 0.1908121109008789
# 	Time: 0.18128085136413574
# 	Time: 0.18855762481689453
# 	Time: 0.17961359024047852
# 	Time: 0.18418192863464355
# 	Time: 0.18409347534179688
# 	Time: 0.19077587127685547
# 	Time: 0.18141460418701172
# 	Time: 0.18612051010131836

# %%
df_categoria = pd.DataFrame(columns=['algoritmo', 'arquivo', 'categoria', 'tempo', 'memoria'])

for algoritmo in data_categoria:
    for arquivo in data_categoria[algoritmo]:
        df_categoria = pd.concat([df_categoria, pd.DataFrame({
            'algoritmo': [algoritmo],
            'arquivo': [arquivo],
            'categoria': [int(arquivo.split('-')[2].split('.')[0])],
            'tempo': [data_categoria[algoritmo][arquivo]['tempo']],
            'memoria': [data_categoria[algoritmo][arquivo]['memoria']]
        })])

df_categoria
# Out:
#        algoritmo            arquivo categoria     tempo memoria
# 0         gulosa    input-10k-1.txt         1  0.187893       1
# 0         gulosa    input-10k-2.txt         2  0.177712       2
# 0         gulosa    input-10k-3.txt         3  0.181785       6
# 0         gulosa    input-10k-4.txt         4  0.203004      11
# 0         gulosa    input-10k-5.txt         5  0.187896      15
# 0         gulosa   input-10k-10.txt        10  0.195629      24
# 0         gulosa   input-10k-20.txt        20  0.203321      24
# 0         gulosa   input-10k-30.txt        30  0.182521      24
# 0         gulosa   input-10k-50.txt        50  0.188920      24
# 0         gulosa   input-10k-75.txt        75  0.181847      24
# 0         gulosa  input-10k-100.txt       100  0.185150      24
# 0  aleatoriedade    input-10k-1.txt         1  0.195261       1
# 0  aleatoriedade    input-10k-2.txt         2  0.179924       2
# 0  aleatoriedade    input-10k-3.txt         3  0.190812       6
# 0  aleatoriedade    input-10k-4.txt         4  0.181281      11
# 0  aleatoriedade    input-10k-5.txt         5  0.188558      15
# 0  aleatoriedade   input-10k-10.txt        10  0.179614      23
# 0  aleatoriedade   input-10k-20.txt        20  0.184182      23
# 0  aleatoriedade   input-10k-30.txt        30  0.184093      23
# 0  aleatoriedade   input-10k-50.txt        50  0.190776      21
# 0  aleatoriedade   input-10k-75.txt        75  0.181415      22
# 0  aleatoriedade  input-10k-100.txt       100  0.186121      22

# %% [markdown]
# - Criando o Dataset para o gráfico de Tempo vs Categorias

# %%
df_categoria_mean = df_categoria.drop(columns=['memoria'])
df_categoria_mean = df_categoria_mean.groupby(['algoritmo', 'arquivo', 'categoria']).mean().reset_index()
df_categoria_mean = df_categoria_mean.sort_values(by=['algoritmo','categoria'])
df_categoria_mean
# Out:
#         algoritmo            arquivo  categoria     tempo
# 0   aleatoriedade    input-10k-1.txt          1  0.195261
# 3   aleatoriedade    input-10k-2.txt          2  0.179924
# 5   aleatoriedade    input-10k-3.txt          3  0.190812
# 7   aleatoriedade    input-10k-4.txt          4  0.181281
# 8   aleatoriedade    input-10k-5.txt          5  0.188558
# 1   aleatoriedade   input-10k-10.txt         10  0.179614
# 4   aleatoriedade   input-10k-20.txt         20  0.184182
# 6   aleatoriedade   input-10k-30.txt         30  0.184093
# 9   aleatoriedade   input-10k-50.txt         50  0.190776
# 10  aleatoriedade   input-10k-75.txt         75  0.181415
# 2   aleatoriedade  input-10k-100.txt        100  0.186121
# 11         gulosa    input-10k-1.txt          1  0.187893
# 14         gulosa    input-10k-2.txt          2  0.177712
# 16         gulosa    input-10k-3.txt          3  0.181785
# 18         gulosa    input-10k-4.txt          4  0.203004
# 19         gulosa    input-10k-5.txt          5  0.187896
# 12         gulosa   input-10k-10.txt         10  0.195629
# 15         gulosa   input-10k-20.txt         20  0.203321
# 17         gulosa   input-10k-30.txt         30  0.182521
# 20         gulosa   input-10k-50.txt         50  0.188920
# 21         gulosa   input-10k-75.txt         75  0.181847
# 13         gulosa  input-10k-100.txt        100  0.185150

# %%
# plotar o tempo por categoria
fig, ax = plt.subplots(figsize=(10, 5))

for algoritmo in df_categoria_mean['algoritmo'].unique():
    df_aux = df_categoria_mean[df_categoria_mean['algoritmo'] == algoritmo]
    ax.plot(df_aux['categoria'], df_aux['tempo'], label=algoritmo)

ax.set_title('Tempo por algoritmo por categoria')
ax.set_xlabel('Categoria')
ax.set_ylabel('Tempo (s)')
ax.legend()
plt.show()

# %% [markdown]
# Ao tentar analisar o gráfico de Tempo vs Categorias, não se pode observar uma tendência clara, pois o tempo de execução é muito variável.

# %% [markdown]
# ## Analisando filmes por categoria

# %% [markdown]
# - Funções auxiliares

# %%
def get_all_filmes(arquivo, arquivo_name, algoritmo):
    with open(arquivo, 'r') as f:
        lines = f.readlines()
        filmes = []
        for line in lines:
            line_split = line.split(' ')
            if len(line_split) < 4:
                continue
            filme = {
                'id': int(line_split[0]),
                'inicio': int(line_split[1]),
                'fim': int(line_split[2]),
                'categoria': int(line_split[3].split('\n')[0]),
                'arquivo': arquivo_name,
                'algoritmo': algoritmo
            }
            filmes.append(filme)
        return filmes

# %% [markdown]
# - Gerando um dataset dos filmes por diferentes números de categorias

# %%
df_filmes = pd.DataFrame(columns=['id', 'inicio', 'fim', 'categoria', 'arquivo', 'algoritmo'])

for algoritmo in data_categoria:
    for arquivo in data_categoria[algoritmo]:
        output_name = 'outputs/'+algoritmo + '_output_categoria_' + arquivo.split('-')[2]
        filmes = get_all_filmes(output_name, arquivo, algoritmo)
        df_filmes = pd.concat([df_filmes, pd.DataFrame(filmes)])

# %%
df_filmes
# Out:
#       id inicio fim categoria            arquivo      algoritmo
# 0   5058      0   0         1    input-10k-1.txt         gulosa
# 0    249      0   0         2    input-10k-2.txt         gulosa
# 1   7652      1   1         1    input-10k-2.txt         gulosa
# 0    745      0   0         1    input-10k-3.txt         gulosa
# 1   6509      1   1         1    input-10k-3.txt         gulosa
# ..   ...    ...  ..       ...                ...            ...
# 17  8282     19  20        71  input-10k-100.txt  aleatoriedade
# 18  1339     20  21         5  input-10k-100.txt  aleatoriedade
# 19  7699     21  22        48  input-10k-100.txt  aleatoriedade
# 20   464     22  23        94  input-10k-100.txt  aleatoriedade
# 21  2644     23  24        11  input-10k-100.txt  aleatoriedade
#
# [348 rows x 6 columns]

# %% [markdown]
# - Salvar os dados em um arquivo csv

# %%
df_filmes.to_csv('df_filmes_categoria.csv', index=False)

# %%
# carrgar o arquivo
df_filmes = pd.read_csv('df_filmes_categoria.csv')
df_filmes
# Out:
#        id  inicio  fim  categoria            arquivo      algoritmo
# 0    5058       0    0          1    input-10k-1.txt         gulosa
# 1     249       0    0          2    input-10k-2.txt         gulosa
# 2    7652       1    1          1    input-10k-2.txt         gulosa
# 3     745       0    0          1    input-10k-3.txt         gulosa
# 4    6509       1    1          1    input-10k-3.txt         gulosa
# ..    ...     ...  ...        ...                ...            ...
# 343  8282      19   20         71  input-10k-100.txt  aleatoriedade
# 344  1339      20   21          5  input-10k-100.txt  aleatoriedade
# 345  7699      21   22         48  input-10k-100.txt  aleatoriedade
# 346   464      22   23         94  input-10k-100.txt  aleatoriedade
# 347  2644      23   24         11  input-10k-100.txt  aleatoriedade
#
# [348 rows x 6 columns]

# %%
df_filmes_count = df_filmes.drop(columns=['id', 'inicio', 'fim'])
df_filmes_count = df_filmes_count.groupby(['algoritmo', 'arquivo', 'categoria']).count().reset_index()
df_filmes_count = df_filmes_count.sort_values(by=['algoritmo','categoria'])
df_filmes_count
# Out:
#          algoritmo            arquivo  categoria
# 0    aleatoriedade    input-10k-1.txt          1
# 29   aleatoriedade    input-10k-2.txt          1
# 31   aleatoriedade   input-10k-20.txt          1
# 46   aleatoriedade    input-10k-3.txt          1
# 49   aleatoriedade   input-10k-30.txt          1
# ..             ...                ...        ...
# 139         gulosa  input-10k-100.txt         79
# 140         gulosa  input-10k-100.txt         83
# 141         gulosa  input-10k-100.txt         96
# 142         gulosa  input-10k-100.txt         98
# 143         gulosa  input-10k-100.txt        100
#
# [223 rows x 3 columns]

# %%
# plotar grafico de dispersão

import numpy as np
fig, ax = plt.subplots(figsize=(20, 10))

for algoritmo in df_filmes_count['algoritmo'].unique():
    # plotar os pontos
    df_aux = df_filmes_count[df_filmes_count['algoritmo'] == algoritmo]
    ax.scatter(df_aux['categoria'], df_aux['arquivo'], label=algoritmo)


ax.set_title('Número de filmes por algoritmo por categoria')
ax.set_xlabel('Categoria')
ax.set_ylabel('Número de filmes')
ax.legend()
plt.show()

# %% [markdown]
# Com esta distribuição, pode-se ver que a quantidade de filmes por categoria vs quantidade de categorias pouco influencia na quantidade de filmes que serão colocados na Maratona de Filmes conforme o número de categorias aumenta.

# %% [markdown]
# ## Conclusões

# %% [markdown]
# Podemos conferir que, a partir destes resultados, não basta apenas escolher um algoritmo para resolver um problema, mas sim, analisar o cenário e escolher o algoritmo que melhor se encaixa.
#
# Caso o problema seja assistir a maior quantidade de filmes, no caso da Maratona de Filmes, podemos utilizar algoritmos como o guloso, e que possui uma vantagem maior quando temos um cenário de mais fimes no nosso arquivo de input.
#
# Caso o problema seja a otimização do tempo do algoritmo, podemos utilizar algoritmos como o aleatório, e que possui uma vantagem maior quando temos um cenário de mais fimes.
#
# Além disso, com estes dados, conseguimos comparar o balanceamento de duas abordagens distintas: exploitation e exploration. No exploitation, o foco é dado a uma única propriedade determinística, que leva a soluções consistentes, porém, pode demandar mais tempo, neste caso. Por outro lado, no exploration, há liberdade para escolhas aleatórias, o que pode levar a soluções mais otimizadas em relação ao tempo, porém, com uma consistência no preenchimento total da Maratona menor.
